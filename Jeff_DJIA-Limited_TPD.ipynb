# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import time
import seaborn as sns

# Initialize Sentiment Anal

# Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from twitterapi import consumer_key, consumer_secret, access_token, access_token_secret

# Alpha Vantage API Key
from AV_apikey import apikey

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), wait_on_rate_limit=True)

# %%
# Do a .json dump to see data
tweet = api.search("DJIA")
# Utilize JSON dumps
print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "search_metadata": {
#         "completed_in": 0.056,
#         "count": 15,
#         "max_id": 982371497854423040,
#         "max_id_str": "982371497854423040",
#         "next_results": "?max_id=982365621735346175&q=DJIA&include_entities=1",
#         "query": "DJIA",
#         "refresh_url": "?since_id=982371497854423040&q=DJIA&include_entities=1",
#         "since_id": 0,
#         "since_id_str": "0"
#     },
#     "statuses": [
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:36:31 +0000 2018",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             0,
#                             13
#                         ],
#                         "text": "StockMarkets"
#                     },
#                     {
#                         "indices": [
#                             47,
#                             55
#                         ],
#                         "text": "Markets"
#                     },
#                     {
#                         "indices": [
#                             62,
#                             71
#                         ],
#                         "text": "DowJones"
#                     },
#                     {
#                         "indices": [
#                             72,
#                             77
#                         ],
#                         "text": "DJIA"
#                     },
#                     {
#                         "indices": [
#                             78,
#                             85
#                         ],
#                         "text": "Nasdaq"
#                     },
#                     {
#                         "indices": [
#                             86,
#                             92
#                         ],
#                         "text": "SP500"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/CNBC/status/98\u2026",
#                         "expanded_url": "https://twitter.com/CNBC/status/982370613728718848",
#                         "indices": [
#                             93,
#                             116
#                         ],
#                         "url": "https://t.co/QGVQXoBnGM"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982371497854423040,
#             "id_str": "982371497854423040",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": true,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "quoted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Fri Apr 06 21:33:00 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/C4vm8HTFVh",
#                             "expanded_url": "https://twitter.com/CNBC/status/982370613728718848/video/1",
#                             "id": 982364982464733185,
#                             "id_str": "982364982464733185",
#                             "indices": [
#                                 43,
#                                 66
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/DaIQJRxXkAEUtif.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/DaIQJRxXkAEUtif.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 360,
#                                     "resize": "fit",
#                                     "w": 639
#                                 },
#                                 "medium": {
#                                     "h": 360,
#                                     "resize": "fit",
#                                     "w": 639
#                                 },
#                                 "small": {
#                                     "h": 360,
#                                     "resize": "fit",
#                                     "w": 639
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "photo",
#                             "url": "https://t.co/C4vm8HTFVh"
#                         }
#                     ],
#                     "symbols": [],
#                     "urls": [],
#                     "user_mentions": []
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "additional_media_info": {
#                                 "call_to_actions": {
#                                     "visit_site": {
#                                         "url": "https://www.cnbc.com?__source=twitter%7Cmain%7Ccta"
#                                     }
#                                 },
#                                 "description": "Dow plunges more than 550 points to end the week as trade war fears rattle Wall Street.",
#                                 "embeddable": true,
#                                 "monetizable": false,
#                                 "title": "Trade fears rattle markets, Dow closes down over 550 points"
#                             },
#                             "display_url": "pic.twitter.com/C4vm8HTFVh",
#                             "expanded_url": "https://twitter.com/CNBC/status/982370613728718848/video/1",
#                             "id": 982364982464733185,
#                             "id_str": "982364982464733185",
#                             "indices": [
#                                 43,
#                                 66
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/DaIQJRxXkAEUtif.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/DaIQJRxXkAEUtif.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 360,
#                                     "resize": "fit",
#                                     "w": 639
#                                 },
#                                 "medium": {
#                                     "h": 360,
#                                     "resize": "fit",
#                                     "w": 639
#                                 },
#                                 "small": {
#                                     "h": 360,
#                                     "resize": "fit",
#                                     "w": 639
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "video",
#                             "url": "https://t.co/C4vm8HTFVh",
#                             "video_info": {
#                                 "aspect_ratio": [
#                                     16,
#                                     9
#                                 ],
#                                 "duration_millis": 61762,
#                                 "variants": [
#                                     {
#                                         "bitrate": 320000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/amplify_video/982364982464733185/vid/320x180/mJzNKfbfN8RYUOJw.mp4"
#                                     },
#                                     {
#                                         "bitrate": 2176000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/amplify_video/982364982464733185/vid/1280x720/DWct4dfqll8uwaVz.mp4"
#                                     },
#                                     {
#                                         "content_type": "application/x-mpegURL",
#                                         "url": "https://video.twimg.com/amplify_video/982364982464733185/pl/ALMYUTCI7GXc8WWR.m3u8"
#                                     },
#                                     {
#                                         "bitrate": 832000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/amplify_video/982364982464733185/vid/640x360/GqpfonUCegJ_S5V-.mp4"
#                                     }
#                                 ]
#                             }
#                         }
#                     ]
#                 },
#                 "favorite_count": 4,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982370613728718848,
#                 "id_str": "982370613728718848",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 6,
#                 "retweeted": false,
#                 "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Media Studio</a>",
#                 "text": "Here's what happened in the markets today. https://t.co/C4vm8HTFVh",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Mon Feb 09 00:03:41 +0000 2009",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "First in Business Worldwide",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "cnbc.com",
#                                     "expanded_url": "http://cnbc.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/xNSucapdhO"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 33,
#                     "follow_request_sent": false,
#                     "followers_count": 2945425,
#                     "following": false,
#                     "friends_count": 515,
#                     "geo_enabled": true,
#                     "has_extended_profile": false,
#                     "id": 20402945,
#                     "id_str": "20402945",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 25293,
#                     "location": "",
#                     "name": "CNBC",
#                     "notifications": false,
#                     "profile_background_color": "0D181F",
#                     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/583652722282377216/qZPzBhcz.png",
#                     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/583652722282377216/qZPzBhcz.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/20402945/1483461609",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/875399584477962241/CsazvyAF_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/875399584477962241/CsazvyAF_normal.jpg",
#                     "profile_link_color": "2D648A",
#                     "profile_sidebar_border_color": "FFFFFF",
#                     "profile_sidebar_fill_color": "EAEBEA",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "CNBC",
#                     "statuses_count": 192371,
#                     "time_zone": "Eastern Time (US & Canada)",
#                     "translator_type": "none",
#                     "url": "https://t.co/xNSucapdhO",
#                     "utc_offset": -14400,
#                     "verified": true
#                 }
#             },
#             "quoted_status_id": 982370613728718848,
#             "quoted_status_id_str": "982370613728718848",
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "text": "#StockMarkets End Down\nHere's what happened in #Markets today\n#DowJones #DJIA #Nasdaq #SP500 https://t.co/QGVQXoBnGM",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sat Nov 09 03:45:23 +0000 2013",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "tiny, old, grey, occasionally a bit cranky\nI Tweet A Lot\nLIST to Save Timeline",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 320360,
#                 "follow_request_sent": false,
#                 "followers_count": 1416,
#                 "following": false,
#                 "friends_count": 178,
#                 "geo_enabled": true,
#                 "has_extended_profile": false,
#                 "id": 2183520866,
#                 "id_str": "2183520866",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 1076,
#                 "location": "Northern California U.S.A.",
#                 "name": "tiniskwerl",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000118283135/381ffa311adf99a106ffb1446ff42c4c.jpeg",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000118283135/381ffa311adf99a106ffb1446ff42c4c.jpeg",
#                 "profile_background_tile": true,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2183520866/1398245990",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/412832329795522562/oxZ13kuE_normal.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/412832329795522562/oxZ13kuE_normal.jpeg",
#                 "profile_link_color": "0057B3",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "tiniskwerl",
#                 "statuses_count": 387130,
#                 "time_zone": "Pacific Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -25200,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:35:45 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/9\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/982371305189240833",
#                         "indices": [
#                             117,
#                             140
#                         ],
#                         "url": "https://t.co/Iwa1qtXhlg"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982371305189240833,
#             "id_str": "982371305189240833",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": true,
#             "lang": "es",
#             "metadata": {
#                 "iso_language_code": "es",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "quoted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Wed Apr 04 20:40:20 +0000 2018",
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "indices": [
#                                 0,
#                                 5
#                             ],
#                             "text": "DJIA"
#                         }
#                     ],
#                     "symbols": [],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/981632581908254721",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/zznQd57p5e"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 2,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 981632581908254721,
#                 "id_str": "981632581908254721",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "es",
#                 "metadata": {
#                     "iso_language_code": "es",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "retweet_count": 0,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#                 "text": "#DJIA \u00ba En 1 solo d\u00eda se puede cambiar el sesgo de bajista a alcista. Hoy el \u00edndice ha demostrado en su directriz p\u2026 https://t.co/zznQd57p5e",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Fri Jan 03 20:38:48 +0000 2014",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "\"La verdadera ignorancia no es la ausencia de conocimientos, sino el hecho de negarse a adquirirlos.\" Karl Popper\n\n\"AMAT VICTORIA CURAM\"",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "favourites_count": 1128,
#                     "follow_request_sent": false,
#                     "followers_count": 510,
#                     "following": false,
#                     "friends_count": 48,
#                     "geo_enabled": true,
#                     "has_extended_profile": false,
#                     "id": 2275060916,
#                     "id_str": "2275060916",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "es",
#                     "listed_count": 21,
#                     "location": "Valladolid, Espa\u00f1a",
#                     "name": "MiguelAAA Alonso",
#                     "notifications": false,
#                     "profile_background_color": "ACDED6",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/2275060916/1518048749",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/937830839450308608/dsH7DQ5F_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/937830839450308608/dsH7DQ5F_normal.jpg",
#                     "profile_link_color": "038543",
#                     "profile_sidebar_border_color": "EEEEEE",
#                     "profile_sidebar_fill_color": "F6F6F6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "MiguelAAA2",
#                     "statuses_count": 6046,
#                     "time_zone": "Madrid",
#                     "translator_type": "none",
#                     "url": null,
#                     "utc_offset": 7200,
#                     "verified": false
#                 }
#             },
#             "quoted_status_id": 981632581908254721,
#             "quoted_status_id_str": "981632581908254721",
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "text": "# DJIA \u00ba En 1 solo d\u00eda se vuelve, otra vez,a cambiar el sesgo de alcista a bajista.Esta vez el ataque a la directri\u2026 https://t.co/Iwa1qtXhlg",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Fri Jan 03 20:38:48 +0000 2014",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "\"La verdadera ignorancia no es la ausencia de conocimientos, sino el hecho de negarse a adquirirlos.\" Karl Popper\n\n\"AMAT VICTORIA CURAM\"",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 1128,
#                 "follow_request_sent": false,
#                 "followers_count": 510,
#                 "following": false,
#                 "friends_count": 48,
#                 "geo_enabled": true,
#                 "has_extended_profile": false,
#                 "id": 2275060916,
#                 "id_str": "2275060916",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "es",
#                 "listed_count": 21,
#                 "location": "Valladolid, Espa\u00f1a",
#                 "name": "MiguelAAA Alonso",
#                 "notifications": false,
#                 "profile_background_color": "ACDED6",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2275060916/1518048749",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/937830839450308608/dsH7DQ5F_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/937830839450308608/dsH7DQ5F_normal.jpg",
#                 "profile_link_color": "038543",
#                 "profile_sidebar_border_color": "EEEEEE",
#                 "profile_sidebar_fill_color": "F6F6F6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "MiguelAAA2",
#                 "statuses_count": 6046,
#                 "time_zone": "Madrid",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": 7200,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:35:12 +0000 2018",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             67,
#                             79
#                         ],
#                         "text": "ThanksTrump"
#                     }
#                 ],
#                 "symbols": [
#                     {
#                         "indices": [
#                             17,
#                             22
#                         ],
#                         "text": "DJIA"
#                     }
#                 ],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 889268122322034688,
#                         "id_str": "889268122322034688",
#                         "indices": [
#                             3,
#                             15
#                         ],
#                         "name": "Alt Georgia",
#                         "screen_name": "Alt_GeOrgia"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982371168450695168,
#             "id_str": "982371168450695168",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 1,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Fri Apr 06 18:09:13 +0000 2018",
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "indices": [
#                                 50,
#                                 62
#                             ],
#                             "text": "ThanksTrump"
#                         }
#                     ],
#                     "symbols": [
#                         {
#                             "indices": [
#                                 0,
#                                 5
#                             ],
#                             "text": "DJIA"
#                         }
#                     ],
#                     "urls": [],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 1,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982319330145767426,
#                 "id_str": "982319330145767426",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "retweet_count": 1,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "text": "$DJIA has plummeted 600 + points. Nice job dotard #ThanksTrump",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sun Jul 23 23:36:56 +0000 2017",
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "description": "Come for the Chick-fil-A, Peaches, and Peanuts. Stay for the Resistance. I watch Fox News so you don't have to. #FireHannity",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "favourites_count": 2333,
#                     "follow_request_sent": false,
#                     "followers_count": 73,
#                     "following": false,
#                     "friends_count": 24,
#                     "geo_enabled": false,
#                     "has_extended_profile": false,
#                     "id": 889268122322034688,
#                     "id_str": "889268122322034688",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 0,
#                     "location": "Georgia, USA",
#                     "name": "Alt Georgia",
#                     "notifications": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/889268122322034688/1509487187",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/925482451320950784/7ZmKoeY0_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/925482451320950784/7ZmKoeY0_normal.jpg",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "Alt_GeOrgia",
#                     "statuses_count": 4293,
#                     "time_zone": null,
#                     "translator_type": "none",
#                     "url": null,
#                     "utc_offset": null,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Lite</a>",
#             "text": "RT @Alt_GeOrgia: $DJIA has plummeted 600 + points. Nice job dotard #ThanksTrump",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Fri Jul 17 22:38:22 +0000 2009",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 27694,
#                 "follow_request_sent": false,
#                 "followers_count": 138,
#                 "following": false,
#                 "friends_count": 196,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 57778956,
#                 "id_str": "57778956",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 3,
#                 "location": "A-T-L",
#                 "name": "JustRead",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/900905201258778625/Fh5Niplx_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/900905201258778625/Fh5Niplx_normal.jpg",
#                 "profile_link_color": "E81C4F",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "jockey4books",
#                 "statuses_count": 34178,
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -14400,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:33:22 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/9\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/982370707115069440",
#                         "indices": [
#                             114,
#                             137
#                         ],
#                         "url": "https://t.co/OlaFO4ajbN"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982370707115069440,
#             "id_str": "982370707115069440",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "text": "DJIA on 11/2/17:  23,516.26 (date the Tax Bill was announced)\nDJIA on 1/20/17:  24,754.06 (date it was signed by\u2026 https://t.co/OlaFO4ajbN",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Wed Jun 24 22:23:25 +0000 2009",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "Facts over truths. Every time. \nIt's easier to fool someone than to convince them they've been fooled. USAF Vet 93-97. Proudly anti-hate.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "howsciencefictionfailed.com",
#                                 "expanded_url": "http://howsciencefictionfailed.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "url": "https://t.co/HE7CcCGOB6"
#                             }
#                         ]
#                     }
#                 },
#                 "favourites_count": 1898,
#                 "follow_request_sent": false,
#                 "followers_count": 884,
#                 "following": false,
#                 "friends_count": 1597,
#                 "geo_enabled": false,
#                 "has_extended_profile": true,
#                 "id": 50461906,
#                 "id_str": "50461906",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 48,
#                 "location": "Here. Not there, here.",
#                 "name": "Phineas \"Facts Over Truths\" Delgado",
#                 "notifications": false,
#                 "profile_background_color": "642D8B",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme10/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme10/bg.gif",
#                 "profile_background_tile": true,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/50461906/1512193492",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/945175220280877056/m7oULEmz_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/945175220280877056/m7oULEmz_normal.jpg",
#                 "profile_link_color": "642D8B",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "686868",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "PhineasDelgado",
#                 "statuses_count": 16804,
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": "https://t.co/HE7CcCGOB6",
#                 "utc_offset": -14400,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:33:04 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/9\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/982370631462211589",
#                         "indices": [
#                             117,
#                             140
#                         ],
#                         "url": "https://t.co/FTn3eBYYZN"
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "id": 25073877,
#                         "id_str": "25073877",
#                         "indices": [
#                             69,
#                             85
#                         ],
#                         "name": "Donald J. Trump",
#                         "screen_name": "realDonaldTrump"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982370631462211589,
#             "id_str": "982370631462211589",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "text": "The 3 biggest 1 day point drops in DJIA history have been this year. @realDonaldTrump Hits just keep on coming. (an\u2026 https://t.co/FTn3eBYYZN",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Wed Feb 02 02:46:53 +0000 2011",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "Old guy just trying to stay relevant",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 1273,
#                 "follow_request_sent": false,
#                 "followers_count": 85,
#                 "following": false,
#                 "friends_count": 94,
#                 "geo_enabled": true,
#                 "has_extended_profile": false,
#                 "id": 246082221,
#                 "id_str": "246082221",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 6,
#                 "location": "Winona",
#                 "name": "tom ryan",
#                 "notifications": false,
#                 "profile_background_color": "131516",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/436298761761869824/sDmMbueF.jpeg",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/436298761761869824/sDmMbueF.jpeg",
#                 "profile_background_tile": true,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/246082221/1386631379",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/955829701481717760/jmNAznop_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/955829701481717760/jmNAznop_normal.jpg",
#                 "profile_link_color": "009999",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "EFEFEF",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "trextr",
#                 "statuses_count": 11434,
#                 "time_zone": "Central Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -18000,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:32:24 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "markets.businessinsider.com/news/stocks/do\u2026",
#                         "expanded_url": "http://markets.businessinsider.com/news/stocks/dow-jones-us-steel-stock-price-getting-whacked-after-trump-threatens-more-tariffs-2018-4-1020700385",
#                         "indices": [
#                             90,
#                             113
#                         ],
#                         "url": "https://t.co/NLdZZWR9yO"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982370460963753985,
#             "id_str": "982370460963753985",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://www.facebook.com/twitter\" rel=\"nofollow\">Facebook</a>",
#             "text": "Stocks are getting whacked after Trump threatens more tariffs (DJIA, X) | Markets Insider https://t.co/NLdZZWR9yO",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Wed Feb 16 22:48:01 +0000 2011",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 823,
#                 "follow_request_sent": false,
#                 "followers_count": 1108,
#                 "following": false,
#                 "friends_count": 1902,
#                 "geo_enabled": true,
#                 "has_extended_profile": false,
#                 "id": 253280555,
#                 "id_str": "253280555",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 106,
#                 "location": "Brooklyn, NY",
#                 "name": "USuncutMN",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/253280555/1444479756",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/747936619924070401/NpnKeZWy_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/747936619924070401/NpnKeZWy_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "USuncutMN",
#                 "statuses_count": 54091,
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -14400,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:31:05 +0000 2018",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             16,
#                             28
# ...
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "69Omic",
#                 "statuses_count": 1444,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:14:24 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "media": [
#                     {
#                         "display_url": "pic.twitter.com/23IKst3CtH",
#                         "expanded_url": "https://twitter.com/JorelLaraKalel/status/982365930842935296/photo/1",
#                         "id": 982365927672041472,
#                         "id_str": "982365927672041472",
#                         "indices": [
#                             113,
#                             136
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/DaIQmz5W0AAgHwt.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/DaIQmz5W0AAgHwt.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 1128,
#                                 "resize": "fit",
#                                 "w": 1220
#                             },
#                             "medium": {
#                                 "h": 1110,
#                                 "resize": "fit",
#                                 "w": 1200
#                             },
#                             "small": {
#                                 "h": 629,
#                                 "resize": "fit",
#                                 "w": 680
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "type": "photo",
#                         "url": "https://t.co/23IKst3CtH"
#                     }
#                 ],
#                 "symbols": [
#                     {
#                         "indices": [
#                             65,
#                             69
#                         ],
#                         "text": "SPY"
#                     },
#                     {
#                         "indices": [
#                             70,
#                             74
#                         ],
#                         "text": "QQQ"
#                     },
#                     {
#                         "indices": [
#                             75,
#                             80
#                         ],
#                         "text": "DJIA"
#                     },
#                     {
#                         "indices": [
#                             81,
#                             85
#                         ],
#                         "text": "DIA"
#                     },
#                     {
#                         "indices": [
#                             86,
#                             90
#                         ],
#                         "text": "SPX"
#                     },
#                     {
#                         "indices": [
#                             91,
#                             94
#                         ],
#                         "text": "DE"
#                     },
#                     {
#                         "indices": [
#                             95,
#                             98
#                         ],
#                         "text": "BA"
#                     },
#                     {
#                         "indices": [
#                             99,
#                             103
#                         ],
#                         "text": "CAT"
#                     },
#                     {
#                         "indices": [
#                             104,
#                             107
#                         ],
#                         "text": "GE"
#                     },
#                     {
#                         "indices": [
#                             108,
#                             112
#                         ],
#                         "text": "MMM"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "bit.ly/2JpSyu1",
#                         "expanded_url": "http://bit.ly/2JpSyu1",
#                         "indices": [
#                             41,
#                             64
#                         ],
#                         "url": "https://t.co/lZZ2XFh6l9"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "display_url": "pic.twitter.com/23IKst3CtH",
#                         "expanded_url": "https://twitter.com/JorelLaraKalel/status/982365930842935296/photo/1",
#                         "id": 982365927672041472,
#                         "id_str": "982365927672041472",
#                         "indices": [
#                             113,
#                             136
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/DaIQmz5W0AAgHwt.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/DaIQmz5W0AAgHwt.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 1128,
#                                 "resize": "fit",
#                                 "w": 1220
#                             },
#                             "medium": {
#                                 "h": 1110,
#                                 "resize": "fit",
#                                 "w": 1200
#                             },
#                             "small": {
#                                 "h": 629,
#                                 "resize": "fit",
#                                 "w": 680
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "type": "photo",
#                         "url": "https://t.co/23IKst3CtH"
#                     }
#                 ]
#             },
#             "favorite_count": 1,
#             "favorited": false,
#             "geo": null,
#             "id": 982365930842935296,
#             "id_str": "982365930842935296",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://stocktwits.com\" rel=\"nofollow\">StockTwits Web</a>",
#             "text": "Stocks falter on growing trade war fears https://t.co/lZZ2XFh6l9 $SPY $QQQ $DJIA $DIA $SPX $DE $BA $CAT $GE $MMM https://t.co/23IKst3CtH",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Aug 15 03:20:37 +0000 2013",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "Marvel, DC, Pixar, Disney, SD Comic-Con, Superman, Stocks, Options",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "twinstalkstocks.com",
#                                 "expanded_url": "http://www.twinstalkstocks.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "url": "https://t.co/diKZDOlU8G"
#                             }
#                         ]
#                     }
#                 },
#                 "favourites_count": 1209,
#                 "follow_request_sent": false,
#                 "followers_count": 4777,
#                 "following": false,
#                 "friends_count": 4711,
#                 "geo_enabled": true,
#                 "has_extended_profile": false,
#                 "id": 1672120591,
#                 "id_str": "1672120591",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 154,
#                 "location": "San Diego, CA",
#                 "name": "Clark Joseph Kent",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/457631730833162240/ulACaLqO.jpeg",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/457631730833162240/ulACaLqO.jpeg",
#                 "profile_background_tile": true,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1672120591/1398406294",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/459575613754310656/qtxdENZ4_normal.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/459575613754310656/qtxdENZ4_normal.jpeg",
#                 "profile_link_color": "B300B3",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "JorelLaraKalel",
#                 "statuses_count": 31473,
#                 "time_zone": "Pacific Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": "https://t.co/diKZDOlU8G",
#                 "utc_offset": -25200,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 21:13:10 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/9\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/982365621735346176",
#                         "indices": [
#                             116,
#                             139
#                         ],
#                         "url": "https://t.co/Iq7gzVFgn5"
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "id": 25073877,
#                         "id_str": "25073877",
#                         "indices": [
#                             0,
#                             16
#                         ],
#                         "name": "Donald J. Trump",
#                         "screen_name": "realDonaldTrump"
#                     },
#                     {
#                         "id": 4857446475,
#                         "id_str": "4857446475",
#                         "indices": [
#                             17,
#                             30
#                         ],
#                         "name": "Bernie & Sid in the Morning",
#                         "screen_name": "bernieandsid"
#                     },
#                     {
#                         "id": 104567779,
#                         "id_str": "104567779",
#                         "indices": [
#                             31,
#                             43
#                         ],
#                         "name": "77 WABC Radio",
#                         "screen_name": "77WABCradio"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982365621735346176,
#             "id_str": "982365621735346176",
#             "in_reply_to_screen_name": "realDonaldTrump",
#             "in_reply_to_status_id": 982353975595929600,
#             "in_reply_to_status_id_str": "982353975595929600",
#             "in_reply_to_user_id": 25073877,
#             "in_reply_to_user_id_str": "25073877",
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "@realDonaldTrump @bernieandsid @77WABCradio Boy, it\u2019s been a long time since you posted one of your \u201cDJIA All time\u2026 https://t.co/Iq7gzVFgn5",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Aug 06 03:55:41 +0000 2009",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "Our best hope is freedom of speech, freedom of the press and the Constitution. Trump will not succeed against the Constitution. I follow back like minded people",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 10787,
#                 "follow_request_sent": false,
#                 "followers_count": 498,
#                 "following": false,
#                 "friends_count": 619,
#                 "geo_enabled": true,
#                 "has_extended_profile": false,
#                 "id": 63362801,
#                 "id_str": "63362801",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 1,
#                 "location": "Stoughton, MA",
#                 "name": "David Rabinow",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme2/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme2/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/976988288245518336/Kjp9ekuP_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/976988288245518336/Kjp9ekuP_normal.jpg",
#                 "profile_link_color": "1B95E0",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "David_Rabinow",
#                 "statuses_count": 7362,
#                 "time_zone": "Quito",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -18000,
#                 "verified": false
#             }
#         }
#     ]
# }

# %%
#pulled from whatever source we're using, set as lists for now, but can be changed
pull_dates = ["2018-04-05", "2018-04-04","2018-04-03","2018-04-02", 
              "2018-03-29", "2018-03-28", "2018-03-27", "2018-03-26", 
              "2018-03-23", "2018-03-22", "2018-03-21", "2018-03-20", "2018-03-19", 
              "2018-03-16", "2018-03-15", "2018-03-14", "2018-03-13", "2018-03-12",
              "2018-03-09", "2018-03-08", "2018-03-07", "2018-03-06", "2018-03-05",
              "2018-03-02", "2018-03-01",]

#pulled from whatever source we're using, set as lists for now, but can be changed
index_name = "DJIA"

#for dataframe

sentiments = []

prev_date = "2018-04-06"
#loop through dates
for date in pull_dates:
    # Counter
    counter = 1
    
    # Get all tweets from home feed
    public_tweets = api.search(index_name, count = 10, since=date, until=prev_date)
    prev_date = date

    # Loop through all tweets 
    for tweet in public_tweets["statuses"]:

        # Print Tweets
        print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        # The following are not needed but I included them for reference
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
            
        date = time.strftime('%m-%d-%Y', time.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
        
        # Add sentiments for each tweet into an array if the language is English
        if tweet["lang"] == "en":
            sentiments.append({"Index": index_name,
                               "Tweet":tweet["text"],
                               "Date": date,
                               "Language": tweet["lang"],
                                "Compound": compound,
                               "Positive": pos,
                               "Negative": neu,
                               "Neutral": neg,
                               "Tweets Ago": counter})
            
        # Add to counter 
        counter = counter + 1
# Out:
# Tweet 1: US Stocks Above 5-DMA [4-Apr]:
#
# $DJIA: 83%
# $SPX:  85%
# $MID:  80%
# $SML:  83%
# $NDX:  87%
# $NYA:  74%
#
# https://t.co/4b93yYPrfh
# Tweet 2: @chlobo_ilo  You reference DJIA as a related security in your article this evening? Did you mean DJX
# Tweet 3: $DJIA https://t.co/SW2CtBUDNs
# Tweet 4: $DJIA  Futures...!!!! https://t.co/U3cDu1G10C
# Tweet 5: Trump asks for $100 billion in additional tariffs on Chinese products - Seriously???  $QQQ $SPX $DJIA https://t.co/z95k8n2beB
# Tweet 6: @marxnd @asibiza1 @notayesmansecon @benbGATech @Financial_Orbit @RonnieChopra1 @jimmhk @elerianm @TheIdleInvestor… https://t.co/egKJhZBEAm
# Tweet 7: $SPY I'd be willing to be big money that we don't open worse than -.60% tomorrow morning...which means there is an… https://t.co/g9mLJK880B
# Tweet 8: RT @MarketWatch: Dow futures tumble as Trump seeks additional $100 billion in tariffs https://t.co/R5KAsAwpG1
# Tweet 9: Halfway to that +8% bounce target with 2 trading days left. Need to clear 2800 before we breath safely $SPX $VIX… https://t.co/GvtUmBINVf
# Tweet 10: RT @IBD_DChung: New In Investor's Corner: Just a thought for now, but if you are expecting more 8% to 12% pullbacks by the major indexes th…
# Tweet 1: $SPX $SPY $DJIA $DIA $COMPQ $QQQ https://t.co/ywGUKfjVRB
# Tweet 2: So far, the 200 day sma is holding on the DJIA daily.
# Tweet 3: RT @DanBehringer221: Break out the rally cap: Dow Jones industrial average turns 500-point loss into 230-point gain on Wednesday. https://t…
# Tweet 4: $SPX $SPY $QQQ $NDX $IWM $VIX $DIA $DJIA $SVXY $UVXY Economic reports for Thursday 4/5 https://t.co/Y2u8thLQqc
# Tweet 5: US Stocks With 5-Day RSI Below 30 [3-Apr]:
#
# $DJIA: 0%
# $SPX:  6%
# $MID:  7%
# $SML:  10%
# $NDX:  18%
#
# https://t.co/4b93yYPrfh
# Tweet 6: RT @TSTRealMoney: The right combination of bad news and gap-down open created ideal conditions for a very feisty reversal. The DJIA reverse…
# Tweet 7: #Dow #DowJones #DJIA gained 0.96% #SP500 up 1.16% #NASDAQ up 1.45% #DJIA YTD still down 1.84% #SP500 YTD still down… https://t.co/FRYcUJoYTI
# Tweet 8: RT @busquetsmarcelo: Mientras #SP500  horario hace máximos decrecientes
#
# $DJIA  hace crecientes,
#
# estas divergencias hay que tenerlas en…
# Tweet 9: Recap of today’s #market activity, #news after the close https://t.co/ArBMEFRgD7 $SPX $DJIA $COMPQ $USD #futures #stocks #economy #earnings
# Tweet 10: Mientras #SP500  horario hace máximos decrecientes
#
# $DJIA  hace crecientes,
#
# estas divergencias hay que tenerlas… https://t.co/zIjTch6aPX
# Tweet 1: Market popped +8% in 4 days last time it survived a 200MA scare in Feb. Here's what that would look like now $SPX… https://t.co/oAf8gxwnOj
# Tweet 2: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 3: RT @JeffersonObama: ■DJIA under Trump since #InaugurationDay +19.3%
# ■DJIA under Obama since #InaugurationDay +149%
# ■S&amp;P500 under Trump sinc…
# Tweet 4: RT @alaidi: key April patterns; US dollar index, equity indices and energy. You'll be surprised with the results.
#
# https://t.co/CnJweJ3z1m…
# Tweet 5: ■NIKKEI225(FUTURES)－4/4－NEUTRAL
# (LAST＠21490）#nikkei
#
# ■NIKKEI225(CASH)－3/29－NEUTRAL
# (LAST＠21292.29）#nikkei
#
# ■DJIA－3/… https://t.co/c24g2664ud
# Tweet 6: Bull's Strategy:Indices/NIKKEI225FUTURES:SELL,DJIA:SELL,SPX:SELL,NASDAQ:SELL,RUSSEL:SELL,FTSE:NEUTRAL,DAX:NEUTRAL(4… https://t.co/Vq4a4HrQhS
# Tweet 7: key April patterns; US dollar index, equity indices and energy. You'll be surprised with the results.… https://t.co/P1AdqQTy26
# Tweet 8: RT @IpotNews: Pasar Wall Street mengakhiri sesi yang volatile lebih tinggi pada perdagangan Selasa, memulihkan sebagian dari kerugian sehar…
# Tweet 9: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 10: @business #MAGA MAKE AMERICA GULLIBLE AGAIN
#
# $SPY $SPX $AMZN $QQQ $TWTR $VIX $ES $ES_F $NQ $DJIA $USD $IWM $F $GM… https://t.co/TNtCNF7Xgu
# Tweet 1: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 2: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 3: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 4: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 5: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 6: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 7: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 8: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 9: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 10: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 1: RT @StockTwits: Trump tweets about the stock market vs. the Dow. Notice anything? 🤦‍♂️ $DIA $DJIA
#
# https://t.co/eMOLhKKWem https://t.co/x33…
# Tweet 2: @liberalwhisper @TimothyKenison @tedlieu @realDonaldTrump Apparently you aren't either. That's a chart of the DJIA, not market volume
# Tweet 3: RT @deviantcharts: $YM $DJIA BEAR MKT 24,500 PJT: TARIFFS AS EXPECTED; NOT A #TRADEWAR IT’S AN ARMS INNOVATION RACE CIRCA 2014 V MERCURIAL…
# Tweet 4: RT @StockTwits: Trump tweets about the stock market vs. the Dow. Notice anything? 🤦‍♂️ $DIA $DJIA
#
# https://t.co/eMOLhKKWem https://t.co/x33…
# Tweet 5: $SPY $DJIA Big down week ahead???
# Tweet 6: $YM $DJIA BEAR MKT 24,500 PJT: TARIFFS AS EXPECTED; NOT A #TRADEWAR IT’S AN ARMS INNOVATION RACE CIRCA 2014 V MERCU… https://t.co/uh2WGd0tQY
# Tweet 7: CLINTON CASH
# https://t.co/4p4A2SGJQ9
# @HillaryClinton @JoeBiden @JohnKerry
#
# $FB $TWTR $DJIA $SPX $NDX $DIA $SPY $QQQ… https://t.co/bkBDpYhgti
# Tweet 8: RT @StockTwits: Trump tweets about the stock market vs. the Dow. Notice anything? 🤦‍♂️ $DIA $DJIA
#
# https://t.co/eMOLhKKWem https://t.co/x33…
# Tweet 9: RT @TraderLionChat: Market Analysis and Summary from tonight's newsletter.
#
# $SPX $DJIA $NDX $RUT $SPY $QQQ $IWM $DIA https://t.co/4D4JrGSa6u
# Tweet 10: RT @StockTwits: Trump tweets about the stock market vs. the Dow. Notice anything? 🤦‍♂️ $DIA $DJIA
#
# https://t.co/eMOLhKKWem https://t.co/x33…
# Tweet 1: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 2: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 3: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 4: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 5: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 6: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 7: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 8: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 9: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 10: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 1: $SPX $SPY $QQQ $NDX $IWM $VIX $DIA $DJIA $SVXY $UVXY Five Things You Need to Know to Start Your Day
#
# https://t.co/s2zGdMCY6c
# Tweet 2: CBA overnight $AUDUSD $EURUSD $GBPUSD $USDJPY $NZDUSD $EURAUD $GBPAUD $DXY $usdcad $USDCHF $SPX $OIL $audnzd $USDX… https://t.co/kkXrJRtFNA
# Tweet 3: RT @JayWoods3: The DJIA sold off 300+ points since this guy stepped onto the floor. https://t.co/uoqm9MYSxA
# Tweet 4: ...this divergence was best recognized by the S&amp;P/DJIA/midcaps' inability to confirm the Nasdaq's new high in mid-M… https://t.co/s4rvaRZuCT
# Tweet 5: $LFIN incredible day here with the puts bought yesterday! +9,100 so far! $SPY $QQQ $IWM $DJIA $VXX $UDOW $VIX https://t.co/M8iOE6zje1
# Tweet 6: RT @bullgokon: ■NIKKEI225(FUTURES)－3/28－SELL＠20710－STOP＠21140
# (LAST＠20710）#nikkei
#
# ■NIKKEI225(CASH)－3/27－NEUTRAL
# 3/23－SELL＠20617.86 ⇒　HIT S…
# Tweet 7: $SPX $SPY $QQQ $NDX $IWM $VIX $DIA $DJIA $SVXY $UVXY Asia Stocks Tip Losses After U.S. Tech Slides: Markets Wrap
#
# https://t.co/dUgOaCG7P6
# Tweet 8: DOW JONES (DJIA) turun 300 poin, Nassau terjungkal 3% https://t.co/4lJZQdiHvG via @saham_indonesia
# Tweet 9: Recap of today’s #market activity, #news after the close https://t.co/ArBMEFRgD7 $SPX $DJIA $COMPQ $USD #futures #stocks #economy #earnings
# Tweet 10: Don’t cry over your loss, cherish the good times you had together $NVDA $TSLA $AMZN $FB $SPY $DJIA $QQQ

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd = sentiments_pd[["Index", "Date", "Language", "Tweets Ago", "Compound", "Positive", "Neutral", "Negative", "Tweet"]]
sentiments_pd.to_csv("DJIA_data.csv")
print(sentiments_pd.shape)
sentiments_pd.tail()
# Out:
# (59, 9)
#    Index        Date Language  Tweets Ago  Compound  Positive  Neutral  \
# 54  DJIA  03-27-2018       en           4    0.3612     0.183    0.118
# 55  DJIA  03-27-2018       en           5    0.0000     0.000    0.000
# 56  DJIA  03-27-2018       en           7   -0.4019     0.000    0.119
# 57  DJIA  03-27-2018       en           9    0.0000     0.000    0.000
# 58  DJIA  03-27-2018       en          10    0.0258     0.212    0.208
#
#     Negative                                              Tweet
# 54     0.699  ...this divergence was best recognized by the ...
# 55     1.000  $LFIN incredible day here with the puts bought...
# 56     0.881  $SPX $SPY $QQQ $NDX $IWM $VIX $DIA $DJIA $SVXY...
# 57     1.000  Recap of today’s #market activity, #news after...
# 58     0.579  Don’t cry over your loss, cherish the good tim...

# %%
# Get the mean sentiment for each date
# Only compound sentiment is needed but I wanted to see all sentiment averages
mean_values = pd.pivot_table(sentiments_pd, index = ["Date"],
                                   values = ("Compound", "Positive", "Neutral", "Negative"), aggfunc=np.mean)

# Flattenning the header to clean up the dataframe for mean values
mean_sentiment = pd.DataFrame(mean_values.to_records())
mean_sentiment = mean_sentiment[["Date", "Compound", "Positive", "Neutral", "Negative"]]
mean_sentiment["Index"] = sentiments_pd["Index"]
mean_sentiment = mean_sentiment[["Date", "Index", "Compound", "Positive", "Neutral", "Negative"]]
mean_sentiment.to_csv("DJIA_sentiment_by_day.csv")

mean_sentiment
# Out:
#          Date Index  Compound  Positive   Neutral  Negative
# 0  03-27-2018  DJIA -0.002129  0.056429  0.063571  0.879857
# 1  03-28-2018  DJIA  0.855300  0.290000  0.000000  0.710000
# 2  04-01-2018  DJIA  0.114667  0.032444  0.000000  0.967556
# 3  04-02-2018  DJIA  0.476700  0.124000  0.000000  0.876000
# 4  04-03-2018  DJIA  0.266488  0.127750  0.031625  0.840625
# 5  04-04-2018  DJIA  0.125900  0.065571  0.032429  0.901857
# 6  04-05-2018  DJIA  0.138475  0.060000  0.016250  0.923750

# %%
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&apikey=demo&datatype=csv
    
# Save config information.
url = "https://www.alphavantage.co/query?"

# Build partial query URL
query_url = f"{url}function=TIME_SERIES_DAILY&symbol={index_name}&apikey={apikey}&datatype=csv"
query_url
# Out:
# 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=DJIA&apikey=72CL7KDAJ55OYYA1&datatype=csv'
