# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import time
import seaborn as sns

# Initialize Sentiment Anal

# Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from twitterapi import consumer_key, consumer_secret, access_token, access_token_secret

# Alpha Vantage API Key
from AV_apikey import apikey

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), wait_on_rate_limit=True)

# %%
# Do a .json dump to see data
tweet = api.search("DJIA")
# Utilize JSON dumps
print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "search_metadata": {
#         "completed_in": 0.046,
#         "count": 15,
#         "max_id": 982617061313560577,
#         "max_id_str": "982617061313560577",
#         "next_results": "?max_id=982609125531152383&q=DJIA&include_entities=1",
#         "query": "DJIA",
#         "refresh_url": "?since_id=982617061313560577&q=DJIA&include_entities=1",
#         "since_id": 0,
#         "since_id_str": "0"
#     },
#     "statuses": [
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Sat Apr 07 13:52:18 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [
#                     {
#                         "indices": [
#                             15,
#                             20
#                         ],
#                         "text": "DJIA"
#                     }
#                 ],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 86537404,
#                         "id_str": "86537404",
#                         "indices": [
#                             3,
#                             13
#                         ],
#                         "name": "Jason Sparks",
#                         "screen_name": "sparksjls"
#                     },
#                     {
#                         "id": 800707492346925056,
#                         "id_str": "800707492346925056",
#                         "indices": [
#                             77,
#                             83
#                         ],
#                         "name": "Axios",
#                         "screen_name": "axios"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982617061313560577,
#             "id_str": "982617061313560577",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 9,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Sat Apr 07 13:18:05 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [
#                         {
#                             "indices": [
#                                 0,
#                                 5
#                             ],
#                             "text": "DJIA"
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/982608450898276357",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/qxSm0z9wHZ"
#                         }
#                     ],
#                     "user_mentions": [
#                         {
#                             "id": 800707492346925056,
#                             "id_str": "800707492346925056",
#                             "indices": [
#                                 62,
#                                 68
#                             ],
#                             "name": "Axios",
#                             "screen_name": "axios"
#                         }
#                     ]
#                 },
#                 "favorite_count": 7,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982608450898276357,
#                 "id_str": "982608450898276357",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": {
#                     "attributes": {},
#                     "bounding_box": {
#                         "coordinates": [
#                             [
#                                 [
#                                     -77.119401,
#                                     38.801826
#                                 ],
#                                 [
#                                     -76.909396,
#                                     38.801826
#                                 ],
#                                 [
#                                     -76.909396,
#                                     38.9953797
#                                 ],
#                                 [
#                                     -77.119401,
#                                     38.9953797
#                                 ]
#                             ]
#                         ],
#                         "type": "Polygon"
#                     },
#                     "contained_within": [],
#                     "country": "United States",
#                     "country_code": "US",
#                     "full_name": "Washington, DC",
#                     "id": "01fbe706f872cb32",
#                     "name": "Washington",
#                     "place_type": "city",
#                     "url": "https://api.twitter.com/1.1/geo/id/01fbe706f872cb32.json"
#                 },
#                 "retweet_count": 9,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "text": "$DJIA return during a president\u2019s first 444 days, ranked (via @axios):\n1\ufe0f\u20e3FDR : 70.4%\n2\ufe0f\u20e3Reagan: 41.4%\n3\ufe0f\u20e3Teddy Roo\u2026 https://t.co/qxSm0z9wHZ",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sat Oct 31 14:30:03 +0000 2009",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Health IT, operations, and health policy. Not Jordin Sparks. Views are mine alone and are not those of my employer.",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "vote.org",
#                                     "expanded_url": "http://vote.org",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/TuEMDk0hkZ"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 41630,
#                     "follow_request_sent": false,
#                     "followers_count": 10779,
#                     "following": false,
#                     "friends_count": 941,
#                     "geo_enabled": true,
#                     "has_extended_profile": true,
#                     "id": 86537404,
#                     "id_str": "86537404",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 223,
#                     "location": "Washington, D.C. ",
#                     "name": "Jason Sparks",
#                     "notifications": false,
#                     "profile_background_color": "F0F0F0",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/86537404/1397493676",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/944963424529866753/Ml-0LvJZ_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/944963424529866753/Ml-0LvJZ_normal.jpg",
#                     "profile_link_color": "0F0B0F",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "sparksjls",
#                     "statuses_count": 78002,
#                     "time_zone": "Eastern Time (US & Canada)",
#                     "translator_type": "none",
#                     "url": "https://t.co/TuEMDk0hkZ",
#                     "utc_offset": -14400,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#             "text": "RT @sparksjls: $DJIA return during a president\u2019s first 444 days, ranked (via @axios):\n1\ufe0f\u20e3FDR : 70.4%\n2\ufe0f\u20e3Reagan: 41.4%\n3\ufe0f\u20e3Teddy Roosevelt: 3\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sat Nov 12 23:14:38 +0000 2016",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "Taking it all in",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "langbros.com",
#                                 "expanded_url": "http://langbros.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "url": "https://t.co/D6xebdLWIY"
#                             }
#                         ]
#                     }
#                 },
#                 "favourites_count": 12753,
#                 "follow_request_sent": false,
#                 "followers_count": 49,
#                 "following": false,
#                 "friends_count": 102,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 797578377490092032,
#                 "id_str": "797578377490092032",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 0,
#                 "location": "Vancouver, BC",
#                 "name": "Susan Lang",
#                 "notifications": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/797578377490092032/1501812570",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/893292776774815745/EhU9w4Ds_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/893292776774815745/EhU9w4Ds_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "Hi_Canada_Rocks",
#                 "statuses_count": 10471,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": "https://t.co/D6xebdLWIY",
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Sat Apr 07 13:47:23 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [
#                     {
#                         "indices": [
#                             15,
#                             20
#                         ],
#                         "text": "DJIA"
#                     }
#                 ],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 86537404,
#                         "id_str": "86537404",
#                         "indices": [
#                             3,
#                             13
#                         ],
#                         "name": "Jason Sparks",
#                         "screen_name": "sparksjls"
#                     },
#                     {
#                         "id": 800707492346925056,
#                         "id_str": "800707492346925056",
#                         "indices": [
#                             77,
#                             83
#                         ],
#                         "name": "Axios",
#                         "screen_name": "axios"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982615825684353027,
#             "id_str": "982615825684353027",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 9,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Sat Apr 07 13:18:05 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [
#                         {
#                             "indices": [
#                                 0,
#                                 5
#                             ],
#                             "text": "DJIA"
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/982608450898276357",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/qxSm0z9wHZ"
#                         }
#                     ],
#                     "user_mentions": [
#                         {
#                             "id": 800707492346925056,
#                             "id_str": "800707492346925056",
#                             "indices": [
#                                 62,
#                                 68
#                             ],
#                             "name": "Axios",
#                             "screen_name": "axios"
#                         }
#                     ]
#                 },
#                 "favorite_count": 7,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982608450898276357,
#                 "id_str": "982608450898276357",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": {
#                     "attributes": {},
#                     "bounding_box": {
#                         "coordinates": [
#                             [
#                                 [
#                                     -77.119401,
#                                     38.801826
#                                 ],
#                                 [
#                                     -76.909396,
#                                     38.801826
#                                 ],
#                                 [
#                                     -76.909396,
#                                     38.9953797
#                                 ],
#                                 [
#                                     -77.119401,
#                                     38.9953797
#                                 ]
#                             ]
#                         ],
#                         "type": "Polygon"
#                     },
#                     "contained_within": [],
#                     "country": "United States",
#                     "country_code": "US",
#                     "full_name": "Washington, DC",
#                     "id": "01fbe706f872cb32",
#                     "name": "Washington",
#                     "place_type": "city",
#                     "url": "https://api.twitter.com/1.1/geo/id/01fbe706f872cb32.json"
#                 },
#                 "retweet_count": 9,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "text": "$DJIA return during a president\u2019s first 444 days, ranked (via @axios):\n1\ufe0f\u20e3FDR : 70.4%\n2\ufe0f\u20e3Reagan: 41.4%\n3\ufe0f\u20e3Teddy Roo\u2026 https://t.co/qxSm0z9wHZ",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sat Oct 31 14:30:03 +0000 2009",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Health IT, operations, and health policy. Not Jordin Sparks. Views are mine alone and are not those of my employer.",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "vote.org",
#                                     "expanded_url": "http://vote.org",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/TuEMDk0hkZ"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 41630,
#                     "follow_request_sent": false,
#                     "followers_count": 10779,
#                     "following": false,
#                     "friends_count": 941,
#                     "geo_enabled": true,
#                     "has_extended_profile": true,
#                     "id": 86537404,
#                     "id_str": "86537404",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 223,
#                     "location": "Washington, D.C. ",
#                     "name": "Jason Sparks",
#                     "notifications": false,
#                     "profile_background_color": "F0F0F0",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/86537404/1397493676",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/944963424529866753/Ml-0LvJZ_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/944963424529866753/Ml-0LvJZ_normal.jpg",
#                     "profile_link_color": "0F0B0F",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "sparksjls",
#                     "statuses_count": 78002,
#                     "time_zone": "Eastern Time (US & Canada)",
#                     "translator_type": "none",
#                     "url": "https://t.co/TuEMDk0hkZ",
#                     "utc_offset": -14400,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#             "text": "RT @sparksjls: $DJIA return during a president\u2019s first 444 days, ranked (via @axios):\n1\ufe0f\u20e3FDR : 70.4%\n2\ufe0f\u20e3Reagan: 41.4%\n3\ufe0f\u20e3Teddy Roosevelt: 3\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Fri Jul 20 00:12:56 +0000 2012",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "Political junkie. Patriot. Optimist. Nerd. Chocolate lover.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 137761,
#                 "follow_request_sent": false,
#                 "followers_count": 942,
#                 "following": false,
#                 "friends_count": 764,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 706049323,
#                 "id_str": "706049323",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 16,
#                 "location": "",
#                 "name": "Unpresidented",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/706049323/1485121987",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/833461875119624192/lxJ0OGX2_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/833461875119624192/lxJ0OGX2_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "dialogician",
#                 "statuses_count": 110058,
#                 "time_zone": "Atlantic Time (Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -10800,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Sat Apr 07 13:46:51 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 2920726547,
#                         "id_str": "2920726547",
#                         "indices": [
#                             3,
#                             15
#                         ],
#                         "name": "Greg5thTrad",
#                         "screen_name": "Greg5thTrad"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982615689793101825,
#             "id_str": "982615689793101825",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 2,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Sat Apr 07 01:16:21 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/982426822569848832",
#                             "indices": [
#                                 120,
#                                 143
#                             ],
#                             "url": "https://t.co/PhQXV1YTno"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 0,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982426822569848832,
#                 "id_str": "982426822569848832",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": {
#                     "attributes": {},
#                     "bounding_box": {
#                         "coordinates": [
#                             [
#                                 [
#                                     -74.607293,
#                                     39.334612
#                                 ],
#                                 [
#                                     -74.5769961,
#                                     39.334612
#                                 ],
#                                 [
#                                     -74.5769961,
#                                     39.368613
#                                 ],
#                                 [
#                                     -74.607293,
#                                     39.368613
#                                 ]
#                             ]
#                         ],
#                         "type": "Polygon"
#                     },
#                     "contained_within": [],
#                     "country": "United States",
#                     "country_code": "US",
#                     "full_name": "Bargaintown, NJ",
#                     "id": "01fc97b92386e326",
#                     "name": "Bargaintown",
#                     "place_type": "city",
#                     "url": "https://api.twitter.com/1.1/geo/id/01fc97b92386e326.json"
#                 },
#                 "possibly_sensitive": false,
#                 "retweet_count": 2,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "text": "Snapshot of this week\u2019s intraday price charts for major equity indices &amp; other asset classes 4/2-4/6 | charts via,\u2026 https://t.co/PhQXV1YTno",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sun Dec 14 02:09:47 +0000 2014",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Proud father, Friend of Bill, Surfer, Trades Stocks, Independent Thinker, & no fan of Big Government & their Media Cohorts",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "favourites_count": 17360,
#                     "follow_request_sent": false,
#                     "followers_count": 566,
#                     "following": false,
#                     "friends_count": 80,
#                     "geo_enabled": true,
#                     "has_extended_profile": false,
#                     "id": 2920726547,
#                     "id_str": "2920726547",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 42,
#                     "location": "New Jersey, USA",
#                     "name": "Greg5thTrad",
#                     "notifications": false,
#                     "profile_background_color": "000000",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/2920726547/1418524537",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/859574367877050368/A-VNdeTh_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/859574367877050368/A-VNdeTh_normal.jpg",
#                     "profile_link_color": "0084B4",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "000000",
#                     "profile_text_color": "000000",
#                     "profile_use_background_image": false,
#                     "protected": false,
#                     "screen_name": "Greg5thTrad",
#                     "statuses_count": 13770,
#                     "time_zone": "Eastern Time (US & Canada)",
#                     "translator_type": "none",
#                     "url": null,
#                     "utc_offset": -14400,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"https://twitter.com/joeknowbest\" rel=\"nofollow\">Twitter JB Web Client</a>",
#             "text": "RT @Greg5thTrad: Snapshot of this week\u2019s intraday price charts for major equity indices &amp; other asset classes 4/2-4/6 | charts via, https:/\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Tue Dec 05 11:59:51 +0000 2017",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 17,
#                 "follow_request_sent": false,
#                 "followers_count": 253,
#                 "following": false,
#                 "friends_count": 0,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 938015057119760384,
#                 "id_str": "938015057119760384",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "es",
#                 "listed_count": 7,
#                 "location": "",
#                 "name": "Joe Best",
#                 "notifications": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/938015057119760384/1512495801",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/938092471334133760/dAApCQjp_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/938092471334133760/dAApCQjp_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "joeknowbest",
#                 "statuses_count": 34720,
#                 "time_zone": "Pacific Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -25200,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Sat Apr 07 13:44:34 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [
#                     {
#                         "indices": [
#                             15,
#                             20
#                         ],
#                         "text": "DJIA"
#                     }
#                 ],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 86537404,
#                         "id_str": "86537404",
#                         "indices": [
#                             3,
#                             13
#                         ],
#                         "name": "Jason Sparks",
#                         "screen_name": "sparksjls"
#                     },
#                     {
#                         "id": 800707492346925056,
#                         "id_str": "800707492346925056",
#                         "indices": [
#                             77,
#                             83
#                         ],
#                         "name": "Axios",
#                         "screen_name": "axios"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982615116242931714,
#             "id_str": "982615116242931714",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 9,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Sat Apr 07 13:18:05 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [
#                         {
#                             "indices": [
#                                 0,
#                                 5
#                             ],
#                             "text": "DJIA"
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/982608450898276357",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/qxSm0z9wHZ"
#                         }
#                     ],
#                     "user_mentions": [
#                         {
#                             "id": 800707492346925056,
#                             "id_str": "800707492346925056",
#                             "indices": [
#                                 62,
#                                 68
#                             ],
#                             "name": "Axios",
#                             "screen_name": "axios"
#                         }
#                     ]
#                 },
#                 "favorite_count": 7,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982608450898276357,
#                 "id_str": "982608450898276357",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": {
#                     "attributes": {},
#                     "bounding_box": {
#                         "coordinates": [
#                             [
#                                 [
#                                     -77.119401,
#                                     38.801826
#                                 ],
#                                 [
#                                     -76.909396,
#                                     38.801826
#                                 ],
#                                 [
#                                     -76.909396,
#                                     38.9953797
#                                 ],
#                                 [
#                                     -77.119401,
#                                     38.9953797
#                                 ]
#                             ]
#                         ],
#                         "type": "Polygon"
#                     },
#                     "contained_within": [],
#                     "country": "United States",
#                     "country_code": "US",
#                     "full_name": "Washington, DC",
#                     "id": "01fbe706f872cb32",
#                     "name": "Washington",
#                     "place_type": "city",
#                     "url": "https://api.twitter.com/1.1/geo/id/01fbe706f872cb32.json"
#                 },
#                 "retweet_count": 9,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "text": "$DJIA return during a president\u2019s first 444 days, ranked (via @axios):\n1\ufe0f\u20e3FDR : 70.4%\n2\ufe0f\u20e3Reagan: 41.4%\n3\ufe0f\u20e3Teddy Roo\u2026 https://t.co/qxSm0z9wHZ",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sat Oct 31 14:30:03 +0000 2009",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Health IT, operations, and health policy. Not Jordin Sparks. Views are mine alone and are not those of my employer.",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "vote.org",
#                                     "expanded_url": "http://vote.org",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/TuEMDk0hkZ"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 41630,
#                     "follow_request_sent": false,
#                     "followers_count": 10779,
#                     "following": false,
#                     "friends_count": 941,
#                     "geo_enabled": true,
#                     "has_extended_profile": true,
#                     "id": 86537404,
#                     "id_str": "86537404",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 223,
#                     "location": "Washington, D.C. ",
#                     "name": "Jason Sparks",
#                     "notifications": false,
#                     "profile_background_color": "F0F0F0",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/86537404/1397493676",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/944963424529866753/Ml-0LvJZ_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/944963424529866753/Ml-0LvJZ_normal.jpg",
#                     "profile_link_color": "0F0B0F",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "sparksjls",
#                     "statuses_count": 78002,
#                     "time_zone": "Eastern Time (US & Canada)",
#                     "translator_type": "none",
#                     "url": "https://t.co/TuEMDk0hkZ",
#                     "utc_offset": -14400,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "RT @sparksjls: $DJIA return during a president\u2019s first 444 days, ranked (via @axios):\n1\ufe0f\u20e3FDR : 70.4%\n2\ufe0f\u20e3Reagan: 41.4%\n3\ufe0f\u20e3Teddy Roosevelt: 3\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Aug 07 21:34:58 +0000 2014",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 34224,
#                 "follow_request_sent": false,
#                 "followers_count": 203,
#                 "following": false,
#                 "friends_count": 1773,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 2715422287,
#                 "id_str": "2715422287",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 6,
#                 "location": "",
#                 "name": "Jon Atkins",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/497505389915545601/pdiIXWJ0_normal.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/497505389915545601/pdiIXWJ0_normal.jpeg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "jonatkins7",
#                 "statuses_count": 5969,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Sat Apr 07 13:43:52 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [
#                     {
#                         "indices": [
#                             32,
#                             37
#                         ],
#                         "text": "DJIA"
#                     },
#                     {
#                         "indices": [
#                             43,
#                             47
#                         ],
#                         "text": "SPX"
#                     },
#                     {
#                         "indices": [
#                             54,
#                             58
#                         ],
#                         "text": "MID"
#                     },
#                     {
#                         "indices": [
#                             65,
#                             69
#                         ],
#                         "text": "SML"
#                     },
#                     {
#                         "indices": [
#                             76,
#                             80
#                         ],
#                         "text": "NDX"
#                     },
#                     {
#                         "indices": [
#                             87,
#                             91
#                         ],
#                         "text": "NYA"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "IndexIndicators.com",
#                         "expanded_url": "http://IndexIndicators.com",
#                         "indices": [
#                             99,
#                             122
#                         ],
#                         "url": "https://t.co/4b93yYPrfh"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982614940736507904,
# ...
#                 "favourites_count": 19314,
#                 "follow_request_sent": false,
#                 "followers_count": 3325,
#                 "following": false,
#                 "friends_count": 3087,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 164053423,
#                 "id_str": "164053423",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 61,
#                 "location": "",
#                 "name": "Lionel Mandrake",
#                 "notifications": false,
#                 "profile_background_color": "254647",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/867852793/274cf2c2d4f7953f9a2f46be2dcc39c9.jpeg",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/867852793/274cf2c2d4f7953f9a2f46be2dcc39c9.jpeg",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/164053423/1368734046",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/3599922361/53990cd9181a7b3753fcbdfc111e402f_normal.png",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/3599922361/53990cd9181a7b3753fcbdfc111e402f_normal.png",
#                 "profile_link_color": "0A7A00",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "Hopsmad",
#                 "statuses_count": 51840,
#                 "time_zone": "Atlantic Time (Canada)",
#                 "translator_type": "none",
#                 "url": "https://t.co/ZFANaLHFgt",
#                 "utc_offset": -10800,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Sat Apr 07 13:23:34 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [
#                     {
#                         "indices": [
#                             103,
#                             108
#                         ],
#                         "text": "DJIA"
#                     }
#                 ],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 36397873,
#                         "id_str": "36397873",
#                         "indices": [
#                             3,
#                             19
#                         ],
#                         "name": "Fox News Research",
#                         "screen_name": "FoxNewsResearch"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982609832346873856,
#             "id_str": "982609832346873856",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 52,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Fri Apr 06 20:10:28 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [
#                         {
#                             "indices": [
#                                 82,
#                                 87
#                             ],
#                             "text": "DJIA"
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/982349841966624778",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/LmjiGjUPlV"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 91,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982349841966624778,
#                 "id_str": "982349841966624778",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 52,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#                 "text": "Stocks Spooked by Possible Trade War:\n\u20223/22: $60B in tariffs on China announced\n\u2192 $DJIA fell 724 pts\n\u20223/23: Day aft\u2026 https://t.co/LmjiGjUPlV",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Wed Apr 29 16:21:22 +0000 2009",
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "description": "Information and analysis from the @FoxNews research team",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "foxnews.com",
#                                     "expanded_url": "http://www.foxnews.com/",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/cYAj6pov2U"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 2,
#                     "follow_request_sent": false,
#                     "followers_count": 46144,
#                     "following": false,
#                     "friends_count": 190,
#                     "geo_enabled": false,
#                     "has_extended_profile": false,
#                     "id": 36397873,
#                     "id_str": "36397873",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 481,
#                     "location": "New York, NY",
#                     "name": "Fox News Research",
#                     "notifications": false,
#                     "profile_background_color": "C0DEED",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/36397873/1507921546",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/921416145302847493/NCfAvjNy_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/921416145302847493/NCfAvjNy_normal.jpg",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "FoxNewsResearch",
#                     "statuses_count": 5507,
#                     "time_zone": "Eastern Time (US & Canada)",
#                     "translator_type": "none",
#                     "url": "https://t.co/cYAj6pov2U",
#                     "utc_offset": -14400,
#                     "verified": true
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "RT @FoxNewsResearch: Stocks Spooked by Possible Trade War:\n\u20223/22: $60B in tariffs on China announced\n\u2192 $DJIA fell 724 pts\n\u20223/23: Day after\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Nov 05 23:09:10 +0000 2009",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 7219,
#                 "follow_request_sent": false,
#                 "followers_count": 84,
#                 "following": false,
#                 "friends_count": 571,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 87809930,
#                 "id_str": "87809930",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 4,
#                 "location": "",
#                 "name": "ZK",
#                 "notifications": false,
#                 "profile_background_color": "022330",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/495021234988797952/wMFtv8DC_normal.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/495021234988797952/wMFtv8DC_normal.jpeg",
#                 "profile_link_color": "0084B4",
#                 "profile_sidebar_border_color": "A8C7F7",
#                 "profile_sidebar_fill_color": "C0DFEC",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "TheKanKan1",
#                 "statuses_count": 8111,
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -14400,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Sat Apr 07 13:20:46 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/9\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/982609125531152384",
#                         "indices": [
#                             117,
#                             140
#                         ],
#                         "url": "https://t.co/cGQAaz6Qp8"
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "id": 25073877,
#                         "id_str": "25073877",
#                         "indices": [
#                             11,
#                             27
#                         ],
#                         "name": "Donald J. Trump",
#                         "screen_name": "realDonaldTrump"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982609125531152384,
#             "id_str": "982609125531152384",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "text": "As usual, .@realDonaldTrump lying, in this case about stock market performance under his administration. For the re\u2026 https://t.co/cGQAaz6Qp8",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sun Mar 12 01:31:03 +0000 2017",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "Fake name for a real DC guy. Fight the infection; the truth is anti-septic.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 16551,
#                 "follow_request_sent": false,
#                 "followers_count": 177,
#                 "following": false,
#                 "friends_count": 1924,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 840736864164335617,
#                 "id_str": "840736864164335617",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 4,
#                 "location": "Tuesday",
#                 "name": "Secretly Psyched",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/840736864164335617/1489323012",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/840801638537396224/G89anMPW_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/840801638537396224/G89anMPW_normal.jpg",
#                 "profile_link_color": "000000",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "SecretlyPsyched",
#                 "statuses_count": 10527,
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -14400,
#                 "verified": false
#             }
#         }
#     ]
# }

# %%
#pulled from whatever source we're using, set as lists for now, but can be changed
pull_dates = ["2018-04-06", "2018-04-05", "2018-04-04","2018-04-03","2018-04-02", 
              "2018-03-29", "2018-03-28", "2018-03-27", "2018-03-26", 
              "2018-03-23", "2018-03-22", "2018-03-21", "2018-03-20", "2018-03-19", 
              "2018-03-16", "2018-03-15", "2018-03-14", "2018-03-13", "2018-03-12",
              "2018-03-09", "2018-03-08", "2018-03-07", "2018-03-06", "2018-03-05",
              "2018-03-02", "2018-03-01",]

#pulled from whatever source we're using, set as lists for now, but can be changed
index_name = "Stock Market"

#for dataframe

sentiments = []

prev_date = "2018-04-07"
#loop through dates
for date in pull_dates:
    # Counter
    counter = 1
    
    # Get all tweets from home feed
    public_tweets = api.search(index_name, count = 10, since=date, until=prev_date)
    prev_date = date

    # Loop through all tweets 
    for tweet in public_tweets["statuses"]:

        # Print Tweets
        print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        # The following are not needed but I included them for reference
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
            
        date = time.strftime('%m-%d-%Y', time.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
        
        # Add sentiments for each tweet into an array if the language is English
        if tweet["lang"] == "en":
            sentiments.append({"Index": index_name,
                               "Tweet":tweet["text"],
                               "Date": date,
                               "Language": tweet["lang"],
                                "Compound": compound,
                               "Positive": pos,
                               "Negative": neu,
                               "Neutral": neg,
                               "Tweets Ago": counter})
            
        # Add to counter 
        counter = counter + 1
# Out:
# Tweet 1: RT @tcsmithbiz: Job growth starting to stagnate
#
# Stock market 20 quarter rally ends
#
# Deficit skyrocketing
#
# Trade war with China hurting ave…
# Tweet 2: @LewTheSpook @up_trumped @djrothkopf @realDonaldTrump Yep.  Unless you own stock and can sell it before he releases… https://t.co/Uu6BxZMcUD
# Tweet 3: RT @RepSwalwell: Stock market is tumbling. You shouldn’t lose money in your  retirement investments because a childish @realDonaldTrump sta…
# Tweet 4: RT @gr8tjude: China tariffs will sting a bit but in the long run it will be good!  https://t.co/o600WFak9Y
# Tweet 5: @realDonaldTrump @bernieandsid @77WABCradio Mr. President u better know what u r doing as your trade war has cost m… https://t.co/zUQST850gm
# Tweet 6: @realDonaldTrump America is a disaster. Thanks for causing the stock market to tank. You're causing all of us to lo… https://t.co/friw5ZbU7g
# Tweet 7: RT @RepSwalwell: Stock market is tumbling. You shouldn’t lose money in your  retirement investments because a childish @realDonaldTrump sta…
# Tweet 8: RT @RepSwalwell: Stock market is tumbling. You shouldn’t lose money in your  retirement investments because a childish @realDonaldTrump sta…
# Tweet 9: RT @gr8tjude: China tariffs will sting a bit but in the long run it will be good!  https://t.co/o600WFak9Y
# Tweet 10: RT @RepSwalwell: Stock market is tumbling. You shouldn’t lose money in your  retirement investments because a childish @realDonaldTrump sta…
# Tweet 1: RT @msleen1970: Jesus Christ Trump wants to add another $100B more on tariffs. I swear he's doing this on purpose. The economy is going to…
# Tweet 2: @_NotFakeNews_ @ateacher97 China holds a lot of US debt, that means if China wants, she could have some fun with th… https://t.co/8a5HM3skog
# Tweet 3: @StopTrump2020 @realDonaldTrump "...at the same time in his Administration."
#
# Stock Market % gain:
#
# Obama:  46.31%… https://t.co/iJhYKNblKX
# Tweet 4: Facebook And Trade Wars: What’s Happening With The Stock Market? https://t.co/fGsJn7hNmr https://t.co/We6DUz1hGt
# Tweet 5: RT @kazweida: The stock market rallied yesterday so I guess Trump thought he’d press his luck. 🙄
#
# There’s a reason this was announced after…
# Tweet 6: @LizAnnSonders Hmm the stock market friendly president? Thanks for the haircut Cheeto boy!
# Tweet 7: Can you believe this moron actually recently said that trade wars are GOOD??? So far it's sent the stock market in… https://t.co/XORkm00lJm
# Tweet 8: RT @kazweida: The stock market rallied yesterday so I guess Trump thought he’d press his luck. 🙄
#
# There’s a reason this was announced after…
# Tweet 9: #Bali #News #investments #Stocks #U.S.A.
#
# Bali news and views editor's comments. It's been a very volatile week in… https://t.co/D8jm5WG07I
# Tweet 10: Bogle on stock turbulence: ‘never seen a market this volatile to this extent in my career’ -  https://t.co/wN5eeVkDjy
# Tweet 1: RT @exoticgamora: US businesses feeling an immediate impact from trump's trade war with China
#
# Businesses that use steel hit with a 25% inc…
# Tweet 2: RT @JasonHalle: WHY IS TRUMP ATTACKING THE STOCK MARKET?
#
# Could it be that he and his billionaire friends are short the market and making B…
# Tweet 3: RT @PhilippeReines: China retaliating against @realDonaldTrump’s tariffs. Stock market plummeting.
#
# But don’t worry. He’ll get Mexico to pa…
# Tweet 4: RT @thehill: White House acknowledges that Trump's new tariffs could create "short-term pain" https://t.co/AAfDcdozkY https://t.co/3NAqgTQI…
# Tweet 5: RT @AriMelber: Facebook knew almost all of this — the apologies only come after forced exposure.
#
# Mark Zuckerberg has avoided testifying s…
# Tweet 6: RT @thehill: White House acknowledges that Trump's new tariffs could create "short-term pain" https://t.co/AAfDcdozkY https://t.co/3NAqgTQI…
# Tweet 7: RT @thehill: White House acknowledges that Trump's new tariffs could create "short-term pain" https://t.co/AAfDcdozkY https://t.co/3NAqgTQI…
# Tweet 8: Business leaders love to celebrate disruption in their rhetoric, but hate when it happens to them. https://t.co/J270fQzD3h
# Tweet 9: RT @Goss30Goss: Stock Market manipulation at the hands of 1 Twitter dumbass should not be allowed to happen in this country. Millions of 40…
# Tweet 10: RT @AriMelber: Facebook knew almost all of this — the apologies only come after forced exposure.
#
# Mark Zuckerberg has avoided testifying s…
# Tweet 1: RT @FoxNews: .@CLewandowski_: “A stock market that continues to go up. A president who’s defending our border, cutting taxes for Americans…
# Tweet 2: RT @mkanau: @GOP, how much more insane does it have to get before you stop Trump, who lacks knowledge, creates chaos, manipulates the stock…
# Tweet 3: RT @mkanau: @GOP, how much more insane does it have to get before you stop Trump, who lacks knowledge, creates chaos, manipulates the stock…
# Tweet 4: RT @FoxNews: .@CLewandowski_: “A stock market that continues to go up. A president who’s defending our border, cutting taxes for Americans…
# Tweet 5: RT @atDavidHoffman: What an abuse of power!
# Trump is using his office to take down a company (Amazon) because he doesn’t like its owner. An…
# Tweet 6: RT @FoxNews: .@CLewandowski_: “A stock market that continues to go up. A president who’s defending our border, cutting taxes for Americans…
# Tweet 7: RT @FoxNews: .@CLewandowski_: “A stock market that continues to go up. A president who’s defending our border, cutting taxes for Americans…
# Tweet 8: RT @goldengateblond: Trump publicly attacked an American company, called the Dept of Justice an “embarassment,” and tanked the stock market…
# Tweet 9: RT @richardhine: The debt has surged to $21 trillion. The stock market is tanking. Meanwhile, Russia is hacking our nuclear plants and the…
# Tweet 10: RT @FoxNews: .@CLewandowski_: “A stock market that continues to go up. A president who’s defending our border, cutting taxes for Americans…
# Tweet 1: RT @atDavidHoffman: Because Trump Doesn’t like the Washington Post telling the truth about him, he attacks the owner’s company, Amazon, sen…
# Tweet 2: RT @AynRandPaulRyan: So. Much. Winning.
#
# BREAKING: U.S. stocks are on track to have their worst April start since 1929, according to data c…
# Tweet 3: RT @aravosis: So @realDonaldTrump’s recklessness is now killing the stock market. If you own Amazon, or any other stock, you just lost a lo…
# Tweet 4: RT @spinderella2525: @ABC Nothing says “Happy Easter, kids” like a bloated, dirty old man bragging about the economy and stock market to a…
# Tweet 5: RT @RogueSNRadvisor: Looking forward to stock market genius @realDonaldTrump taking credit for the 700pt Dow drop today....
# .
# .
# .
# .
# .
# .
# .…
# Tweet 6: RT @Steve03343829: Of course he's not bragging about the stock market it's crashing https://t.co/6G9UnU5sYh
# Tweet 7: RT @goldengateblond: Trump publicly attacked an American company, called the Dept of Justice an “embarassment,” and tanked the stock market…
# Tweet 8: RT @RBReich: Why did the stock market tank today? One word: Trump.
#
# 1) China has responded to Trump with tariffs on American exports -- th…
# Tweet 9: RT @goldengateblond: Trump publicly attacked an American company, called the Dept of Justice an “embarassment,” and tanked the stock market…
# Tweet 10: RT @goldengateblond: Trump publicly attacked an American company, called the Dept of Justice an “embarassment,” and tanked the stock market…
# Tweet 1: RT @charliekirk11: Dems 2018 platform:
#
# Bring back ISIS
# There are no genders
# Open borders
# Repeal 2nd amendment
# Illegals over veterans…
# Tweet 2: @mww1969_mike @WeThePeopleWon @HuffPost And guess what? Trump has nothing to do with the stock market.
# Tweet 3: RT @charliekirk11: Dems 2018 platform:
#
# Bring back ISIS
# There are no genders
# Open borders
# Repeal 2nd amendment
# Illegals over veterans…
# Tweet 4: US Stock Market: 5 Keys To April Direction https://t.co/rZ5v2OnAVG https://t.co/EBOLyCj5Ks
# Tweet 1: https://t.co/PcFgabePL4 https://t.co/PcFgabePL4
# Tweet 2: Four Market-Based Indicators That May Help Investors Identify Stock Market Fragility https://t.co/SS1tOGdCUB
# Tweet 3: @thehill Of course we aren’t! The #TaxScamBill wasn’t meant for us. It was meant for big business &amp; the rich. And w… https://t.co/4dJ2Cc59nL
# Tweet 4: Stock Market Trading AMZN Pre-Market First 2 Hours Opening Bell Short Huges Puts! https://t.co/dfyrwC9g1O
# Tweet 5: RT @OMGno2trump: Keep count #MAGA:
# - 60 Trump administration officials have now been fired, quit, indicted for a felony or plead guilty to…
# Tweet 6: RT @toddmillionaire: ‘Todd Capital Millionaire Podcast Ep 58: Stock market investing basics with Corporate Coke and TRUMP’ on #SoundCloud #…
# Tweet 7: @WhiteHouse More selective Glee Club reporting from the Narcissist-in-Chief ... but those of us outside the Trumpla… https://t.co/6pnESf8Azu
# Tweet 8: @wesley_jordan @Amerikabeau2 @realDonaldTrump The puppet master of the stock market. Think he gets an ego boost in… https://t.co/QfJmwUlJeo
# Tweet 9: RT @BrexitBin: Actually, we didn"t.
# Between losing the empire and joining the EEC, we had:
#
# Suez
# Industrial decline
# Lost textile industry
# R…
# Tweet 10: RT @MarsBars6116: Stock market experts have predicted another economic recession by the end of 2019.
#
# When do you think another recession…

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd = sentiments_pd[["Index", "Date", "Language", "Tweets Ago", "Compound", "Positive", "Neutral", "Negative", "Tweet"]]
sentiments_pd.to_csv("SM_data.csv")
print(sentiments_pd.shape)
sentiments_pd.tail()
# Out:
# (63, 9)
#            Index        Date Language  Tweets Ago  Compound  Positive  \
# 58  Stock Market  03-28-2018       en           6    0.0000     0.000
# 59  Stock Market  03-28-2018       en           7    0.4096     0.139
# 60  Stock Market  03-28-2018       en           8    0.4019     0.137
# 61  Stock Market  03-28-2018       en           9   -0.5994     0.000
# 62  Stock Market  03-28-2018       en          10   -0.4215     0.000
#
#     Neutral  Negative                                              Tweet
# 58    0.000     1.000  RT @toddmillionaire: ‘Todd Capital Millionaire...
# 59    0.000     0.861  @WhiteHouse More selective Glee Club reporting...
# 60    0.000     0.863  @wesley_jordan @Amerikabeau2 @realDonaldTrump ...
# 61    0.197     0.803  RT @BrexitBin: Actually, we didn"t.\nBetween l...
# 62    0.123     0.877  RT @MarsBars6116: Stock market experts have pr...

# %%
# Get the mean sentiment for each date
# Only compound sentiment is needed but I wanted to see all sentiment averages
mean_values = pd.pivot_table(sentiments_pd, index = ["Date"],
                                   values = ("Compound", "Positive", "Neutral", "Negative"), aggfunc=np.mean)

# Flattenning the header to clean up the dataframe for mean values
mean_sentiment = pd.DataFrame(mean_values.to_records())
mean_sentiment = mean_sentiment[["Date", "Compound", "Positive", "Neutral", "Negative"]]
mean_sentiment["Index"] = sentiments_pd["Index"]
mean_sentiment = mean_sentiment[["Date", "Index", "Compound", "Positive", "Neutral", "Negative"]]
mean_sentiment.to_csv("SM_sentiment_by_day.csv")

mean_sentiment
# Out:
#          Date         Index  Compound  Positive  Neutral  Negative
# 0  03-28-2018  Stock Market -0.009022  0.069222   0.0750  0.855778
# 1  04-01-2018  Stock Market -0.148000  0.000000   0.0520  0.948000
# 2  04-02-2018  Stock Market -0.011140  0.107500   0.1072  0.785200
# 3  04-03-2018  Stock Market -0.291150  0.036100   0.1319  0.832000
# 4  04-04-2018  Stock Market -0.446710  0.070500   0.1895  0.740000
# 5  04-05-2018  Stock Market  0.107670  0.107500   0.0666  0.825800
# 6  04-06-2018  Stock Market -0.215930  0.087200   0.1601  0.752700

# %%
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&apikey=demo&datatype=csv
    
# Save config information.
url = "https://www.alphavantage.co/query?"

# Build partial query URL
query_url = f"{url}function=TIME_SERIES_DAILY&symbol={index_name}&apikey={apikey}&datatype=csv"
query_url
# Out:
# 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=Stock Market&apikey=72CL7KDAJ55OYYA1&datatype=csv'
