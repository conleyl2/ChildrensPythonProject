# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import time
import seaborn as sns

# Initialize Sentiment Anal

# Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from twitterapi import consumer_key, consumer_secret, access_token, access_token_secret

# Alpha Vantage API Key
from AV_apikey import apikey

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), wait_on_rate_limit=True)

# %%
# Do a .json dump to see data
tweet = api.search("DJIA")
# Utilize JSON dumps
print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "search_metadata": {
#         "completed_in": 0.062,
#         "count": 15,
#         "max_id": 982343875019784192,
#         "max_id_str": "982343875019784192",
#         "next_results": "?max_id=982341544827957247&q=DJIA&include_entities=1",
#         "query": "DJIA",
#         "refresh_url": "?since_id=982343875019784192&q=DJIA&include_entities=1",
#         "since_id": 0,
#         "since_id_str": "0"
#     },
#     "statuses": [
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 19:46:45 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "media": [
#                     {
#                         "display_url": "pic.twitter.com/EFt3XgrgqC",
#                         "expanded_url": "https://twitter.com/StockTwits/status/982327964523225089/photo/1",
#                         "id": 982327901554081796,
#                         "id_str": "982327901554081796",
#                         "indices": [
#                             102,
#                             125
#                         ],
#                         "media_url": "http://pbs.twimg.com/tweet_video_thumb/DaHuBZkWAAQ7Pdh.jpg",
#                         "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DaHuBZkWAAQ7Pdh.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 270,
#                                 "resize": "fit",
#                                 "w": 480
#                             },
#                             "medium": {
#                                 "h": 270,
#                                 "resize": "fit",
#                                 "w": 480
#                             },
#                             "small": {
#                                 "h": 270,
#                                 "resize": "fit",
#                                 "w": 480
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "source_status_id": 982327964523225089,
#                         "source_status_id_str": "982327964523225089",
#                         "source_user_id": 14886375,
#                         "source_user_id_str": "14886375",
#                         "type": "photo",
#                         "url": "https://t.co/EFt3XgrgqC"
#                     }
#                 ],
#                 "symbols": [
#                     {
#                         "indices": [
#                             70,
#                             75
#                         ],
#                         "text": "DJIA"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "stocktwits.com/GregRieben/mes\u2026",
#                         "expanded_url": "https://stocktwits.com/GregRieben/message/119057665",
#                         "indices": [
#                             78,
#                             101
#                         ],
#                         "url": "https://t.co/re0HMe4wS8"
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "id": 14886375,
#                         "id_str": "14886375",
#                         "indices": [
#                             3,
#                             14
#                         ],
#                         "name": "StockTwits",
#                         "screen_name": "StockTwits"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "display_url": "pic.twitter.com/EFt3XgrgqC",
#                         "expanded_url": "https://twitter.com/StockTwits/status/982327964523225089/photo/1",
#                         "id": 982327901554081796,
#                         "id_str": "982327901554081796",
#                         "indices": [
#                             102,
#                             125
#                         ],
#                         "media_url": "http://pbs.twimg.com/tweet_video_thumb/DaHuBZkWAAQ7Pdh.jpg",
#                         "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DaHuBZkWAAQ7Pdh.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 270,
#                                 "resize": "fit",
#                                 "w": 480
#                             },
#                             "medium": {
#                                 "h": 270,
#                                 "resize": "fit",
#                                 "w": 480
#                             },
#                             "small": {
#                                 "h": 270,
#                                 "resize": "fit",
#                                 "w": 480
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "source_status_id": 982327964523225089,
#                         "source_status_id_str": "982327964523225089",
#                         "source_user_id": 14886375,
#                         "source_user_id_str": "14886375",
#                         "type": "animated_gif",
#                         "url": "https://t.co/EFt3XgrgqC",
#                         "video_info": {
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ],
#                             "variants": [
#                                 {
#                                     "bitrate": 0,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/tweet_video/DaHuBZkWAAQ7Pdh.mp4"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982343875019784192,
#             "id_str": "982343875019784192",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 21,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Fri Apr 06 18:43:32 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/EFt3XgrgqC",
#                             "expanded_url": "https://twitter.com/StockTwits/status/982327964523225089/photo/1",
#                             "id": 982327901554081796,
#                             "id_str": "982327901554081796",
#                             "indices": [
#                                 86,
#                                 109
#                             ],
#                             "media_url": "http://pbs.twimg.com/tweet_video_thumb/DaHuBZkWAAQ7Pdh.jpg",
#                             "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DaHuBZkWAAQ7Pdh.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 270,
#                                     "resize": "fit",
#                                     "w": 480
#                                 },
#                                 "medium": {
#                                     "h": 270,
#                                     "resize": "fit",
#                                     "w": 480
#                                 },
#                                 "small": {
#                                     "h": 270,
#                                     "resize": "fit",
#                                     "w": 480
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "photo",
#                             "url": "https://t.co/EFt3XgrgqC"
#                         }
#                     ],
#                     "symbols": [
#                         {
#                             "indices": [
#                                 54,
#                                 59
#                             ],
#                             "text": "DJIA"
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "display_url": "stocktwits.com/GregRieben/mes\u2026",
#                             "expanded_url": "https://stocktwits.com/GregRieben/message/119057665",
#                             "indices": [
#                                 62,
#                                 85
#                             ],
#                             "url": "https://t.co/re0HMe4wS8"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/EFt3XgrgqC",
#                             "expanded_url": "https://twitter.com/StockTwits/status/982327964523225089/photo/1",
#                             "id": 982327901554081796,
#                             "id_str": "982327901554081796",
#                             "indices": [
#                                 86,
#                                 109
#                             ],
#                             "media_url": "http://pbs.twimg.com/tweet_video_thumb/DaHuBZkWAAQ7Pdh.jpg",
#                             "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DaHuBZkWAAQ7Pdh.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 270,
#                                     "resize": "fit",
#                                     "w": 480
#                                 },
#                                 "medium": {
#                                     "h": 270,
#                                     "resize": "fit",
#                                     "w": 480
#                                 },
#                                 "small": {
#                                     "h": 270,
#                                     "resize": "fit",
#                                     "w": 480
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "animated_gif",
#                             "url": "https://t.co/EFt3XgrgqC",
#                             "video_info": {
#                                 "aspect_ratio": [
#                                     16,
#                                     9
#                                 ],
#                                 "variants": [
#                                     {
#                                         "bitrate": 0,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/tweet_video/DaHuBZkWAAQ7Pdh.mp4"
#                                     }
#                                 ]
#                             }
#                         }
#                     ]
#                 },
#                 "favorite_count": 33,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982327964523225089,
#                 "id_str": "982327964523225089",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 21,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#                 "text": "The Dow is down 671 POINTS right now. Or about -2.7%. $DJIA \n\nhttps://t.co/re0HMe4wS8 https://t.co/EFt3XgrgqC",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Fri May 23 20:53:49 +0000 2008",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Join the largest social network of investors and traders working together to beat the markets. Always free. Get our iOS or Android app: https://t.co/obEPmmpv52",
#                     "entities": {
#                         "description": {
#                             "urls": [
#                                 {
#                                     "display_url": "onelink.to/8h5j9e",
#                                     "expanded_url": "http://onelink.to/8h5j9e",
#                                     "indices": [
#                                         136,
#                                         159
#                                     ],
#                                     "url": "https://t.co/obEPmmpv52"
#                                 }
#                             ]
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "stocktwits.com",
#                                     "expanded_url": "http://www.stocktwits.com",
#                                     "indices": [
#                                         0,
#                                         22
#                                     ],
#                                     "url": "http://t.co/yyRNBE6l4N"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 27881,
#                     "follow_request_sent": false,
#                     "followers_count": 601767,
#                     "following": false,
#                     "friends_count": 125359,
#                     "geo_enabled": true,
#                     "has_extended_profile": false,
#                     "id": 14886375,
#                     "id_str": "14886375",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 8841,
#                     "location": "New York, NY",
#                     "name": "StockTwits",
#                     "notifications": false,
#                     "profile_background_color": "FFFFFF",
#                     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/371870912/stocktwits_twitter_bg.gif",
#                     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/371870912/stocktwits_twitter_bg.gif",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/14886375/1436931698",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/732185372206059520/Jgc_b1iQ_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/732185372206059520/Jgc_b1iQ_normal.jpg",
#                     "profile_link_color": "40576F",
#                     "profile_sidebar_border_color": "DDDDDD",
#                     "profile_sidebar_fill_color": "EEEEEE",
#                     "profile_text_color": "171717",
#                     "profile_use_background_image": false,
#                     "protected": false,
#                     "screen_name": "StockTwits",
#                     "statuses_count": 60353,
#                     "time_zone": "Pacific Time (US & Canada)",
#                     "translator_type": "none",
#                     "url": "http://t.co/yyRNBE6l4N",
#                     "utc_offset": -25200,
#                     "verified": true
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "RT @StockTwits: The Dow is down 671 POINTS right now. Or about -2.7%. $DJIA \n\nhttps://t.co/re0HMe4wS8 https://t.co/EFt3XgrgqC",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sun Jun 17 12:03:16 +0000 2012",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 9315,
#                 "follow_request_sent": false,
#                 "followers_count": 72,
#                 "following": false,
#                 "friends_count": 110,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 610750496,
#                 "id_str": "610750496",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "de",
#                 "listed_count": 3,
#                 "location": "Deutschland",
#                 "name": "this_is_germany",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/610750496/1499504010",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/757511525653438464/ytw-tdpu_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/757511525653438464/ytw-tdpu_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "this_is_germany",
#                 "statuses_count": 9555,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 19:46:44 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 1362696308,
#                         "id_str": "1362696308",
#                         "indices": [
#                             0,
#                             11
#                         ],
#                         "name": "Sharad Jhunjhunwala",
#                         "screen_name": "sharadjhun"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982343872377380864,
#             "id_str": "982343872377380864",
#             "in_reply_to_screen_name": "sharadjhun",
#             "in_reply_to_status_id": 982332805328719873,
#             "in_reply_to_status_id_str": "982332805328719873",
#             "in_reply_to_user_id": 1362696308,
#             "in_reply_to_user_id_str": "1362696308",
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "text": "@sharadjhun DJIA is is still respecting the low made on 4 April .",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Tue Sep 27 05:12:57 +0000 2011",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "Market profile learner",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 151,
#                 "follow_request_sent": false,
#                 "followers_count": 12,
#                 "following": false,
#                 "friends_count": 19,
#                 "geo_enabled": false,
#                 "has_extended_profile": true,
#                 "id": 380752419,
#                 "id_str": "380752419",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 1,
#                 "location": "\u0928\u0935\u0940 \u092e\u0941\u0902\u092c\u0908, \u092d\u093e\u0930\u0924",
#                 "name": "asit kumar routray",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/842607255447130112/BqF0wB8w_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/842607255447130112/BqF0wB8w_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "AsitRoutray",
#                 "statuses_count": 145,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 19:46:20 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/9\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/982343768035635200",
#                         "indices": [
#                             117,
#                             140
#                         ],
#                         "url": "https://t.co/Il83UigvpC"
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "id": 22815781,
#                         "id_str": "22815781",
#                         "indices": [
#                             0,
#                             10
#                         ],
#                         "name": "Kip Herriage",
#                         "screen_name": "KHerriage"
#                     },
#                     {
#                         "id": 19400611,
#                         "id_str": "19400611",
#                         "indices": [
#                             11,
#                             19
#                         ],
#                         "name": "Charles V Payne",
#                         "screen_name": "cvpayne"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982343768035635200,
#             "id_str": "982343768035635200",
#             "in_reply_to_screen_name": "KHerriage",
#             "in_reply_to_status_id": 942050451981328384,
#             "in_reply_to_status_id_str": "942050451981328384",
#             "in_reply_to_user_id": 22815781,
#             "in_reply_to_user_id_str": "22815781",
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "@KHerriage @cvpayne Exactly right. A quick peek at the DJIA since 1928 shows that this huuuuge rise started with th\u2026 https://t.co/Il83UigvpC",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sun Oct 22 13:52:40 +0000 2017",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "Your friendly neighborhood Goodfella.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 1388,
#                 "follow_request_sent": false,
#                 "followers_count": 67,
#                 "following": false,
#                 "friends_count": 264,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 922098380020445184,
#                 "id_str": "922098380020445184",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 0,
#                 "location": "Enterprise, NV",
#                 "name": "BossJayCross",
#                 "notifications": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/922098380020445184/1510507364",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/929761135330410496/BWVOyorb_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/929761135330410496/BWVOyorb_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "BossJayCross1",
#                 "statuses_count": 483,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 19:45:45 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": []
#             },
#             "favorite_count": 13,
#             "favorited": false,
#             "geo": null,
#             "id": 982343622145212416,
#             "id_str": "982343622145212416",
#             "in_reply_to_screen_name": "ComfortablySmug",
#             "in_reply_to_status_id": 982343288995885057,
#             "in_reply_to_status_id_str": "982343288995885057",
#             "in_reply_to_user_id": 17060573,
#             "in_reply_to_user_id_str": "17060573",
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "text": "ICYMI\n\nDJIA = The People's Index\nS&amp;P= The Establishment Index",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Oct 30 05:18:03 +0000 2008",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "My Interests: Finance, Whiskey, Politics, Books, Food, Meeting Strangers\n#altcenter",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 188270,
#                 "follow_request_sent": false,
#                 "followers_count": 68961,
#                 "following": false,
#                 "friends_count": 4479,
#                 "geo_enabled": false,
#                 "has_extended_profile": true,
#                 "id": 17060573,
#                 "id_str": "17060573",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 1372,
#                 "location": "New York, New York",
#                 "name": "Comfortably Smug",
#                 "notifications": false,
#                 "profile_background_color": "B81A1A",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/76411746/1.jpg",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/76411746/1.jpg",
#                 "profile_background_tile": true,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/17060573/1522415569",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/844574503833358336/Hfk6USEJ_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/844574503833358336/Hfk6USEJ_normal.jpg",
#                 "profile_link_color": "B81A1A",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "070808",
#                 "profile_text_color": "5E5E5E",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "ComfortablySmug",
#                 "statuses_count": 253660,
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -14400,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 19:45:23 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [
#                     {
#                         "indices": [
#                             12,
#                             17
#                         ],
#                         "text": "DJIA"
#                     }
#                 ],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 2421067430,
#                         "id_str": "2421067430",
#                         "indices": [
#                             0,
#                             11
#                         ],
#                         "name": "Tea Pain",
#                         "screen_name": "TeaPainUSA"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982343531460050944,
#             "id_str": "982343531460050944",
#             "in_reply_to_screen_name": "TeaPainUSA",
#             "in_reply_to_status_id": 982332821686685699,
#             "in_reply_to_status_id_str": "982332821686685699",
#             "in_reply_to_user_id": 2421067430,
#             "in_reply_to_user_id_str": "2421067430",
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "text": "@TeaPainUSA $DJIA selling selling... time to dump everything? I expect a crash by the fall.",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Tue Feb 14 16:31:06 +0000 2017",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "Bird-watcher. Grass jelly enthusiast. Secondhand collector. Reluctant social media user - duty calls in times of crisis.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 6038,
#                 "follow_request_sent": false,
#                 "followers_count": 89,
#                 "following": false,
#                 "friends_count": 28,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 831541283793534976,
#                 "id_str": "831541283793534976",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 0,
#                 "location": "",
#                 "name": "W. Dust",
#                 "notifications": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/831558275099455488/TOvBWaR2_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/831558275099455488/TOvBWaR2_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "WDust00",
#                 "statuses_count": 12385,
#                 "time_zone": "Pacific Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -25200,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 19:45:07 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [
#                     {
#                         "indices": [
#                             127,
#                             132
#                         ],
#                         "text": "tran"
#                     }
#                 ],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 214577440,
#                         "id_str": "214577440",
#                         "indices": [
#                             3,
#                             19
#                         ],
#                         "name": "Marcelo Busquets",
#                         "screen_name": "busquetsmarcelo"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982343462203817984,
#             "id_str": "982343462203817984",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "es",
#             "metadata": {
#                 "iso_language_code": "es",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 3,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Fri Apr 06 19:04:52 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [
#                         {
#                             "indices": [
#                                 106,
#                                 111
#                             ],
#                             "text": "tran"
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/982333336420077568",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/iJfHEq2Lpm"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 3,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982333336420077568,
#                 "id_str": "982333336420077568",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "es",
#                 "metadata": {
#                     "iso_language_code": "es",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 3,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#                 "text": "Dow Jones Transportes precede a DJIA, en enero clav\u00f3 el techo, luego lo hizo el DJIA, \n\nahora atentos que $tran nos\u2026 https://t.co/iJfHEq2Lpm",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Thu Nov 11 18:47:23 +0000 2010",
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "description": "Gr\u00e1ficos\n\n marbus@servicoopsa.com.ar \n\n54 9 (341) 6589759",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "marcelobusquets.com.ar",
#                                     "expanded_url": "http://www.marcelobusquets.com.ar",
#                                     "indices": [
#                                         0,
#                                         22
#                                     ],
#                                     "url": "http://t.co/KIl1UEtEwT"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 10992,
#                     "follow_request_sent": false,
#                     "followers_count": 9791,
#                     "following": false,
#                     "friends_count": 542,
#                     "geo_enabled": true,
#                     "has_extended_profile": false,
#                     "id": 214577440,
#                     "id_str": "214577440",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "es",
#                     "listed_count": 308,
#                     "location": "Piedritas, BA, Argentina",
#                     "name": "Marcelo Busquets",
#                     "notifications": false,
#                     "profile_background_color": "C0DEED",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/214577440/1396449795",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/577157514170478593/qHXuVujM_normal.jpeg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/577157514170478593/qHXuVujM_normal.jpeg",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "busquetsmarcelo",
#                     "statuses_count": 52012,
#                     "time_zone": "Buenos Aires",
#                     "translator_type": "none",
#                     "url": "http://t.co/KIl1UEtEwT",
#                     "utc_offset": -10800,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://www.twitter.com\" rel=\"nofollow\">Twitter for Windows</a>",
#             "text": "RT @busquetsmarcelo: Dow Jones Transportes precede a DJIA, en enero clav\u00f3 el techo, luego lo hizo el DJIA, \n\nahora atentos que $tran nos pu\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sat Aug 24 01:39:23 +0000 2013",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "finance market | energy | infrastructure | smart city | social development | pymes | education | agroindustry | commodities | geopolitics | mkt | blockchain |",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 50101,
#                 "follow_request_sent": false,
#                 "followers_count": 1987,
#                 "following": false,
#                 "friends_count": 4912,
#                 "geo_enabled": true,
#                 "has_extended_profile": true,
#                 "id": 1695269539,
#                 "id_str": "1695269539",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "es",
#                 "listed_count": 35,
#                 "location": "Argentina",
#                 "name": "Bruno Blanco",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1695269539/1499749728",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/958689321351081984/PiIP1LAs_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/958689321351081984/PiIP1LAs_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "brunoblanco1310",
#                 "statuses_count": 27129,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 19:44:08 +0000 2018",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             47,
#                             51
#                         ],
#                         "text": "MSM"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 897687785427140610,
#                         "id_str": "897687785427140610",
#                         "indices": [
#                             3,
#                             18
#                         ],
#                         "name": "Donald Russo",
#                         "screen_name": "donaldrusso994"
#                     },
#                     {
#                         "id": 822215679726100480,
#                         "id_str": "822215679726100480",
#                         "indices": [
#                             39,
#                             45
#                         ],
#                         "name": "President Trump",
#                         "screen_name": "POTUS"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 982343218246303749,
#             "id_str": "982343218246303749",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": true,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "quoted_status_id": 982214297160839173,
#             "quoted_status_id_str": "982214297160839173",
# ...
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Apr 22 21:19:57 +0000 2010",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 24766,
#                 "follow_request_sent": false,
#                 "followers_count": 64,
#                 "following": false,
#                 "friends_count": 240,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 136031143,
#                 "id_str": "136031143",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 0,
#                 "location": "NYC/NJ Area",
#                 "name": "Dolls",
#                 "notifications": false,
#                 "profile_background_color": "352726",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme5/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme5/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/932983245179969537/ageP-cES_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/932983245179969537/ageP-cES_normal.jpg",
#                 "profile_link_color": "D02B55",
#                 "profile_sidebar_border_color": "829D5E",
#                 "profile_sidebar_fill_color": "99CC33",
#                 "profile_text_color": "3E4415",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "Lolasabel",
#                 "statuses_count": 4598,
#                 "time_zone": "Quito",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -18000,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Apr 06 19:37:29 +0000 2018",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             6,
#                             11
#                         ],
#                         "text": "ES_F"
#                     },
#                     {
#                         "indices": [
#                             27,
#                             35
#                         ],
#                         "text": "Traders"
#                     },
#                     {
#                         "indices": [
#                             37,
#                             44
#                         ],
#                         "text": "NASDAQ"
#                     }
#                 ],
#                 "symbols": [
#                     {
#                         "indices": [
#                             13,
#                             18
#                         ],
#                         "text": "DJIA"
#                     },
#                     {
#                         "indices": [
#                             20,
#                             25
#                         ],
#                         "text": "ES_F"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/Stalingrad_Poo\u2026",
#                         "expanded_url": "https://twitter.com/Stalingrad_Poor/status/982330399798870016",
#                         "indices": [
#                             45,
#                             68
#                         ],
#                         "url": "https://t.co/RgugbzdOPh"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 1,
#             "favorited": false,
#             "geo": null,
#             "id": 982341544827957248,
#             "id_str": "982341544827957248",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": true,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "quoted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Fri Apr 06 18:53:12 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/gwlPrlwZIB",
#                             "expanded_url": "https://twitter.com/Stalingrad_Poor/status/982330399798870016/photo/1",
#                             "id": 982330336351666177,
#                             "id_str": "982330336351666177",
#                             "indices": [
#                                 45,
#                                 68
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/DaHwPH5UwAE3h8a.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/DaHwPH5UwAE3h8a.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 450,
#                                     "resize": "fit",
#                                     "w": 600
#                                 },
#                                 "medium": {
#                                     "h": 450,
#                                     "resize": "fit",
#                                     "w": 600
#                                 },
#                                 "small": {
#                                     "h": 450,
#                                     "resize": "fit",
#                                     "w": 600
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "photo",
#                             "url": "https://t.co/gwlPrlwZIB"
#                         }
#                     ],
#                     "symbols": [],
#                     "urls": [],
#                     "user_mentions": []
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/gwlPrlwZIB",
#                             "expanded_url": "https://twitter.com/Stalingrad_Poor/status/982330399798870016/photo/1",
#                             "id": 982330336351666177,
#                             "id_str": "982330336351666177",
#                             "indices": [
#                                 45,
#                                 68
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/DaHwPH5UwAE3h8a.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/DaHwPH5UwAE3h8a.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 450,
#                                     "resize": "fit",
#                                     "w": 600
#                                 },
#                                 "medium": {
#                                     "h": 450,
#                                     "resize": "fit",
#                                     "w": 600
#                                 },
#                                 "small": {
#                                     "h": 450,
#                                     "resize": "fit",
#                                     "w": 600
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "photo",
#                             "url": "https://t.co/gwlPrlwZIB"
#                         }
#                     ]
#                 },
#                 "favorite_count": 51,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 982330399798870016,
#                 "id_str": "982330399798870016",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 20,
#                 "retweeted": false,
#                 "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#                 "text": "Spoos -70 handles. Retail Investors trapped. https://t.co/gwlPrlwZIB",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Wed Jun 05 14:37:07 +0000 2013",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "The Federal Reserve is not currently forecasting a recession -Ben Bernanke January 10, 2008. In the unlikely event markets are red, please dial (212) 720-6130.",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "zerohedge.com/blogs/stalingr\u2026",
#                                     "expanded_url": "http://www.zerohedge.com/blogs/stalingradandpoorski",
#                                     "indices": [
#                                         0,
#                                         22
#                                     ],
#                                     "url": "http://t.co/GbIj6Qh24a"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 2774,
#                     "follow_request_sent": false,
#                     "followers_count": 22714,
#                     "following": false,
#                     "friends_count": 1346,
#                     "geo_enabled": false,
#                     "has_extended_profile": false,
#                     "id": 1485188648,
#                     "id_str": "1485188648",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 606,
#                     "location": "33 Liberty Street, NYC",
#                     "name": "Stalingrad & Poorski",
#                     "notifications": false,
#                     "profile_background_color": "C0DEED",
#                     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/432777615556870145/nUgS2c65.png",
#                     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/432777615556870145/nUgS2c65.png",
#                     "profile_background_tile": true,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1485188648/1438644451",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/3758989483/8bbb8ff12073264882e766b71b9cd66e_normal.png",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3758989483/8bbb8ff12073264882e766b71b9cd66e_normal.png",
#                     "profile_link_color": "0084B4",
#                     "profile_sidebar_border_color": "FFFFFF",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "Stalingrad_Poor",
#                     "statuses_count": 33271,
#                     "time_zone": "Pacific Time (US & Canada)",
#                     "translator_type": "none",
#                     "url": "http://t.co/GbIj6Qh24a",
#                     "utc_offset": -25200,
#                     "verified": false
#                 }
#             },
#             "quoted_status_id": 982330399798870016,
#             "quoted_status_id_str": "982330399798870016",
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "text": "LOL!  #ES_F, $DJIA, $ES_F, #Traders, #NASDAQ https://t.co/RgugbzdOPh",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Feb 02 23:24:00 +0000 2012",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "22 Year Equity & Futures Trader. Likes-VPIN; Fractal Geometry; Signal Processing Algos; Machine Learning. Dislikes-Elliot Wave; Fibonacci; and all other voodoo.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 934,
#                 "follow_request_sent": false,
#                 "followers_count": 403,
#                 "following": false,
#                 "friends_count": 88,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 481588395,
#                 "id_str": "481588395",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 29,
#                 "location": "Chicago, IL",
#                 "name": "Notes.From.the.Pit",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/850029532681838593/RCRP6lJH_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/850029532681838593/RCRP6lJH_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "NoteFromThePit",
#                 "statuses_count": 3951,
#                 "time_zone": "Central Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -18000,
#                 "verified": false
#             }
#         }
#     ]
# }

# %%
#pulled from whatever source we're using, set as lists for now, but can be changed
pull_dates = ["2018-04-05", "2018-04-04","2018-04-03","2018-04-02", 
              "2018-03-29", "2018-03-28", "2018-03-27", "2018-03-26", 
              "2018-03-23", "2018-03-22", "2018-03-21", "2018-03-20", "2018-03-19", 
              "2018-03-16", "2018-03-15", "2018-03-14", "2018-03-13", "2018-03-12",
              "2018-03-09", "2018-03-08", "2018-03-07", "2018-03-06", "2018-03-05",
              "2018-03-02", "2018-03-01",]

#pulled from whatever source we're using, set as lists for now, but can be changed
index_name = "DJIA"

#for dataframe

sentiments = []

prev_date = "2018-04-06"
#loop through dates
for date in pull_dates:
    # Counter
    counter = 1
    
    # Get all tweets from home feed
    public_tweets = api.search(index_name, count = 10, since=date, until=prev_date)
    prev_date = date

    # Loop through all tweets 
    for tweet in public_tweets["statuses"]:

        # Print Tweets
        print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        # The following are not needed but I included them for reference
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
            
        date = time.strftime('%m-%d-%Y', time.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
        
        # Add sentiments for each tweet into an array if the language is English
        if tweet["lang"] == "en":
            sentiments.append({"Index": index_name,
                               "Tweet":tweet["text"],
                               "Date": date,
                               "Language": tweet["lang"],
                                "Compound": compound,
                               "Positive": pos,
                               "Negative": neu,
                               "Neutral": neg,
                               "Tweets Ago": counter})
            
        # Add to counter 
        counter = counter + 1
# Out:
# Tweet 1: US Stocks Above 5-DMA [4-Apr]:
#
# $DJIA: 83%
# $SPX:  85%
# $MID:  80%
# $SML:  83%
# $NDX:  87%
# $NYA:  74%
#
# https://t.co/4b93yYPrfh
# Tweet 2: @chlobo_ilo  You reference DJIA as a related security in your article this evening? Did you mean DJX
# Tweet 3: $DJIA https://t.co/SW2CtBUDNs
# Tweet 4: $DJIA  Futures...!!!! https://t.co/U3cDu1G10C
# Tweet 5: Trump asks for $100 billion in additional tariffs on Chinese products - Seriously???  $QQQ $SPX $DJIA https://t.co/z95k8n2beB
# Tweet 6: @marxnd @asibiza1 @notayesmansecon @benbGATech @Financial_Orbit @RonnieChopra1 @jimmhk @elerianm @TheIdleInvestor… https://t.co/egKJhZBEAm
# Tweet 7: $SPY I'd be willing to be big money that we don't open worse than -.60% tomorrow morning...which means there is an… https://t.co/g9mLJK880B
# Tweet 8: RT @MarketWatch: Dow futures tumble as Trump seeks additional $100 billion in tariffs https://t.co/R5KAsAwpG1
# Tweet 9: Halfway to that +8% bounce target with 2 trading days left. Need to clear 2800 before we breath safely $SPX $VIX… https://t.co/GvtUmBINVf
# Tweet 10: RT @IBD_DChung: New In Investor's Corner: Just a thought for now, but if you are expecting more 8% to 12% pullbacks by the major indexes th…
# Tweet 1: $SPX $SPY $DJIA $DIA $COMPQ $QQQ https://t.co/ywGUKfjVRB
# Tweet 2: So far, the 200 day sma is holding on the DJIA daily.
# Tweet 3: RT @DanBehringer221: Break out the rally cap: Dow Jones industrial average turns 500-point loss into 230-point gain on Wednesday. https://t…
# Tweet 4: $SPX $SPY $QQQ $NDX $IWM $VIX $DIA $DJIA $SVXY $UVXY Economic reports for Thursday 4/5 https://t.co/Y2u8thLQqc
# Tweet 5: US Stocks With 5-Day RSI Below 30 [3-Apr]:
#
# $DJIA: 0%
# $SPX:  6%
# $MID:  7%
# $SML:  10%
# $NDX:  18%
#
# https://t.co/4b93yYPrfh
# Tweet 6: RT @TSTRealMoney: The right combination of bad news and gap-down open created ideal conditions for a very feisty reversal. The DJIA reverse…
# Tweet 7: #Dow #DowJones #DJIA gained 0.96% #SP500 up 1.16% #NASDAQ up 1.45% #DJIA YTD still down 1.84% #SP500 YTD still down… https://t.co/FRYcUJoYTI
# Tweet 8: RT @busquetsmarcelo: Mientras #SP500  horario hace máximos decrecientes
#
# $DJIA  hace crecientes,
#
# estas divergencias hay que tenerlas en…
# Tweet 9: Recap of today’s #market activity, #news after the close https://t.co/ArBMEFRgD7 $SPX $DJIA $COMPQ $USD #futures #stocks #economy #earnings
# Tweet 10: Mientras #SP500  horario hace máximos decrecientes
#
# $DJIA  hace crecientes,
#
# estas divergencias hay que tenerlas… https://t.co/zIjTch6aPX
# Tweet 1: Market popped +8% in 4 days last time it survived a 200MA scare in Feb. Here's what that would look like now $SPX… https://t.co/oAf8gxwnOj
# Tweet 2: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 3: RT @JeffersonObama: ■DJIA under Trump since #InaugurationDay +19.3%
# ■DJIA under Obama since #InaugurationDay +149%
# ■S&amp;P500 under Trump sinc…
# Tweet 4: RT @alaidi: key April patterns; US dollar index, equity indices and energy. You'll be surprised with the results.
#
# https://t.co/CnJweJ3z1m…
# Tweet 5: ■NIKKEI225(FUTURES)－4/4－NEUTRAL
# (LAST＠21490）#nikkei
#
# ■NIKKEI225(CASH)－3/29－NEUTRAL
# (LAST＠21292.29）#nikkei
#
# ■DJIA－3/… https://t.co/c24g2664ud
# Tweet 6: Bull's Strategy:Indices/NIKKEI225FUTURES:SELL,DJIA:SELL,SPX:SELL,NASDAQ:SELL,RUSSEL:SELL,FTSE:NEUTRAL,DAX:NEUTRAL(4… https://t.co/Vq4a4HrQhS
# Tweet 7: key April patterns; US dollar index, equity indices and energy. You'll be surprised with the results.… https://t.co/P1AdqQTy26
# Tweet 8: RT @IpotNews: Pasar Wall Street mengakhiri sesi yang volatile lebih tinggi pada perdagangan Selasa, memulihkan sebagian dari kerugian sehar…
# Tweet 9: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 10: @business #MAGA MAKE AMERICA GULLIBLE AGAIN
#
# $SPY $SPX $AMZN $QQQ $TWTR $VIX $ES $ES_F $NQ $DJIA $USD $IWM $F $GM… https://t.co/TNtCNF7Xgu
# Tweet 1: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 2: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 3: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 4: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 5: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 6: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 7: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 8: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 9: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 10: RT @AngrierWHStaff: Someone should really take a look at the trading moves made by POTUS’ close friends and family when he makes these outl…
# Tweet 1: RT @StockTwits: Trump tweets about the stock market vs. the Dow. Notice anything? 🤦‍♂️ $DIA $DJIA
#
# https://t.co/eMOLhKKWem https://t.co/x33…
# Tweet 2: @liberalwhisper @TimothyKenison @tedlieu @realDonaldTrump Apparently you aren't either. That's a chart of the DJIA, not market volume
# Tweet 3: RT @deviantcharts: $YM $DJIA BEAR MKT 24,500 PJT: TARIFFS AS EXPECTED; NOT A #TRADEWAR IT’S AN ARMS INNOVATION RACE CIRCA 2014 V MERCURIAL…
# Tweet 4: RT @StockTwits: Trump tweets about the stock market vs. the Dow. Notice anything? 🤦‍♂️ $DIA $DJIA
#
# https://t.co/eMOLhKKWem https://t.co/x33…
# Tweet 5: $SPY $DJIA Big down week ahead???
# Tweet 6: $YM $DJIA BEAR MKT 24,500 PJT: TARIFFS AS EXPECTED; NOT A #TRADEWAR IT’S AN ARMS INNOVATION RACE CIRCA 2014 V MERCU… https://t.co/uh2WGd0tQY
# Tweet 7: CLINTON CASH
# https://t.co/4p4A2SGJQ9
# @HillaryClinton @JoeBiden @JohnKerry
#
# $FB $TWTR $DJIA $SPX $NDX $DIA $SPY $QQQ… https://t.co/bkBDpYhgti
# Tweet 8: RT @StockTwits: Trump tweets about the stock market vs. the Dow. Notice anything? 🤦‍♂️ $DIA $DJIA
#
# https://t.co/eMOLhKKWem https://t.co/x33…
# Tweet 9: RT @TraderLionChat: Market Analysis and Summary from tonight's newsletter.
#
# $SPX $DJIA $NDX $RUT $SPY $QQQ $IWM $DIA https://t.co/4D4JrGSa6u
# Tweet 10: RT @StockTwits: Trump tweets about the stock market vs. the Dow. Notice anything? 🤦‍♂️ $DIA $DJIA
#
# https://t.co/eMOLhKKWem https://t.co/x33…
# Tweet 1: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 2: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 3: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 4: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 5: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 6: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 7: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 8: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 9: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 10: RT @ChrisLutolf: Attn: "@POTUS"
# Do you know the saying "An honest man's word's as good as his bond"?
# Good!
# Are you a man whom one can take…
# Tweet 1: $SPX $SPY $QQQ $NDX $IWM $VIX $DIA $DJIA $SVXY $UVXY Five Things You Need to Know to Start Your Day
#
# https://t.co/s2zGdMCY6c
# Tweet 2: CBA overnight $AUDUSD $EURUSD $GBPUSD $USDJPY $NZDUSD $EURAUD $GBPAUD $DXY $usdcad $USDCHF $SPX $OIL $audnzd $USDX… https://t.co/kkXrJRtFNA
# Tweet 3: RT @JayWoods3: The DJIA sold off 300+ points since this guy stepped onto the floor. https://t.co/uoqm9MYSxA
# Tweet 4: ...this divergence was best recognized by the S&amp;P/DJIA/midcaps' inability to confirm the Nasdaq's new high in mid-M… https://t.co/s4rvaRZuCT
# Tweet 5: $LFIN incredible day here with the puts bought yesterday! +9,100 so far! $SPY $QQQ $IWM $DJIA $VXX $UDOW $VIX https://t.co/M8iOE6zje1
# Tweet 6: RT @bullgokon: ■NIKKEI225(FUTURES)－3/28－SELL＠20710－STOP＠21140
# (LAST＠20710）#nikkei
#
# ■NIKKEI225(CASH)－3/27－NEUTRAL
# 3/23－SELL＠20617.86 ⇒　HIT S…
# Tweet 7: $SPX $SPY $QQQ $NDX $IWM $VIX $DIA $DJIA $SVXY $UVXY Asia Stocks Tip Losses After U.S. Tech Slides: Markets Wrap
#
# https://t.co/dUgOaCG7P6
# Tweet 8: DOW JONES (DJIA) turun 300 poin, Nassau terjungkal 3% https://t.co/4lJZQdiHvG via @saham_indonesia
# Tweet 9: Recap of today’s #market activity, #news after the close https://t.co/ArBMEFRgD7 $SPX $DJIA $COMPQ $USD #futures #stocks #economy #earnings
# Tweet 10: Don’t cry over your loss, cherish the good times you had together $NVDA $TSLA $AMZN $FB $SPY $DJIA $QQQ

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd = sentiments_pd[["Index", "Date", "Language", "Tweets Ago", "Compound", "Positive", "Neutral", "Negative", "Tweet"]]
sentiments_pd.to_csv("DJIA_data.csv")
print(sentiments_pd.shape)
sentiments_pd.tail()
# Out:
# (59, 9)
#    Index        Date Language  Tweets Ago  Compound  Positive  Neutral  \
# 54  DJIA  03-27-2018       en           4    0.3612     0.183    0.118
# 55  DJIA  03-27-2018       en           5    0.0000     0.000    0.000
# 56  DJIA  03-27-2018       en           7   -0.4019     0.000    0.119
# 57  DJIA  03-27-2018       en           9    0.0000     0.000    0.000
# 58  DJIA  03-27-2018       en          10    0.0258     0.212    0.208
#
#     Negative                                              Tweet
# 54     0.699  ...this divergence was best recognized by the ...
# 55     1.000  $LFIN incredible day here with the puts bought...
# 56     0.881  $SPX $SPY $QQQ $NDX $IWM $VIX $DIA $DJIA $SVXY...
# 57     1.000  Recap of today’s #market activity, #news after...
# 58     0.579  Don’t cry over your loss, cherish the good tim...

# %%
# Get the mean sentiment for each date
# Only compound sentiment is needed but I wanted to see all sentiment averages
mean_values = pd.pivot_table(sentiments_pd, index = ["Date"],
                                   values = ("Compound", "Positive", "Neutral", "Negative"), aggfunc=np.mean)

# Flattenning the header to clean up the dataframe for mean values
mean_sentiment = pd.DataFrame(mean_values.to_records())
mean_sentiment = mean_sentiment[["Date", "Compound", "Positive", "Neutral", "Negative"]]
mean_sentiment["Index"] = sentiments_pd["Index"]
mean_sentiment = mean_sentiment[["Date", "Index", "Compound", "Positive", "Neutral", "Negative"]]
mean_sentiment.to_csv("DJIA_sentiment_by_day.csv")

mean_sentiment
# Out:
#          Date Index  Compound  Positive   Neutral  Negative
# 0  03-27-2018  DJIA -0.002129  0.056429  0.063571  0.879857
# 1  03-28-2018  DJIA  0.855300  0.290000  0.000000  0.710000
# 2  04-01-2018  DJIA  0.114667  0.032444  0.000000  0.967556
# 3  04-02-2018  DJIA  0.476700  0.124000  0.000000  0.876000
# 4  04-03-2018  DJIA  0.266488  0.127750  0.031625  0.840625
# 5  04-04-2018  DJIA  0.125900  0.065571  0.032429  0.901857
# 6  04-05-2018  DJIA  0.138475  0.060000  0.016250  0.923750

# %%
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&apikey=demo&datatype=csv
    
# Save config information.
url = "https://www.alphavantage.co/query?"

# Build partial query URL
query_url = f"{url}function=TIME_SERIES_DAILY&symbol={index_name}&apikey={apikey}&datatype=csv"
